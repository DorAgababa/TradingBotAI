# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['next_5_min']
    x = data.drop('next_5_min')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.781022 ┆ -0.780106 ┆ -0.779407 ┆ -0.274536 │
# │ -0.779862 ┆ -0.780807 ┆ -0.780042 ┆ -0.297566 │
# │ -0.78201  ┆ -0.782142 ┆ -0.780891 ┆ -0.467761 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.779856    │
# │ -0.782004    │
# │ -0.778978    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1),return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=75
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (92100, 4)
# y_train is (92100, 1)
# x_train_prepared is (81048, 10, 4)
# y_train_prepared is (81048, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=0, 
    regular_layer1_size=0, 
    regular_layer2_size=0,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.0005, 
    epochs=100
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 0.3345 - mean_absolute_error: 0.3311 - mean_absolute_percentage_error: 60.9892 - val_loss: 0.0034 - val_mean_absolute_error: 0.0306 - val_mean_absolute_percentage_error: 19.2901
# Epoch 2/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - loss: 0.0034 - mean_absolute_error: 0.0300 - mean_absolute_percentage_error: 21.2215 - val_loss: 0.0019 - val_mean_absolute_error: 0.0143 - val_mean_absolute_percentage_error: 11.5782
# Epoch 3/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0019 - mean_absolute_error: 0.0141 - mean_absolute_percentage_error: 14.2113 - val_loss: 0.0017 - val_mean_absolute_error: 0.0104 - val_mean_absolute_percentage_error: 11.4471
# Epoch 4/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0017 - mean_absolute_error: 0.0104 - mean_absolute_percentage_error: 9.7286 - val_loss: 0.0015 - val_mean_absolute_error: 0.0084 - val_mean_absolute_percentage_error: 9.9317
# Epoch 5/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - loss: 0.0015 - mean_absolute_error: 0.0082 - mean_absolute_percentage_error: 8.7681 - val_loss: 0.0014 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 9.1632
# Epoch 6/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - loss: 0.0014 - mean_absolute_error: 0.0066 - mean_absolute_percentage_error: 8.1129 - val_loss: 0.0014 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 5.9752
# Epoch 7/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 0.0013 - mean_absolute_error: 0.0055 - mean_absolute_percentage_error: 6.2276 - val_loss: 0.0013 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 5.7888
# Epoch 8/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 0.0013 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 5.9727 - val_loss: 0.0012 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 5.0539
# Epoch 9/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 52ms/step - loss: 0.0012 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 6.1523 - val_loss: 0.0011 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 5.5391
# Epoch 10/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - loss: 0.0011 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 5.9985 - val_loss: 0.0011 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 5.1666
# Epoch 11/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 62ms/step - loss: 0.0011 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 6.0875 - val_loss: 0.0010 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 5.4302
# Epoch 12/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 64ms/step - loss: 0.0010 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 5.2386 - val_loss: 9.7066e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 5.5740
# Epoch 13/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 77ms/step - loss: 9.5853e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.3991 - val_loss: 9.1873e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 5.6800
# Epoch 14/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 25s 93ms/step - loss: 9.1094e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.9036 - val_loss: 8.7116e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 5.5615
# Epoch 15/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 89ms/step - loss: 8.6438e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.8138 - val_loss: 8.2563e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 5.0904
# Epoch 16/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 85ms/step - loss: 8.1828e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.4455 - val_loss: 7.8619e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 5.3646
# Epoch 17/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - loss: 7.7523e-04 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.9687 - val_loss: 7.4192e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 5.7059
# Epoch 18/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 102ms/step - loss: 7.3523e-04 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 5.8228 - val_loss: 7.0146e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 5.2652
# Epoch 19/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 97ms/step - loss: 6.9414e-04 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.4388 - val_loss: 6.6505e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.8335
# Epoch 20/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 84ms/step - loss: 6.5590e-04 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.2602 - val_loss: 6.2839e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.7617
# Epoch 21/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 94ms/step - loss: 6.2077e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.6953 - val_loss: 5.9674e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.7441
# Epoch 22/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 91ms/step - loss: 5.8786e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.5125 - val_loss: 5.6252e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 4.0860
# Epoch 23/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 79ms/step - loss: 5.6128e-04 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.3993 - val_loss: 5.3224e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 4.1196
# Epoch 24/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 134ms/step - loss: 5.2497e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.5515 - val_loss: 5.0393e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 4.3433
# Epoch 25/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 91ms/step - loss: 4.9709e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 5.5537 - val_loss: 4.7799e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.8037
# Epoch 26/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 98ms/step - loss: 4.7111e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.5558 - val_loss: 4.4941e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.9855
# Epoch 27/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - loss: 4.4530e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 4.5522 - val_loss: 4.2453e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 4.2123
# Epoch 28/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 4.1941e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 4.2924 - val_loss: 4.0279e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 4.0815
# Epoch 29/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 25s 116ms/step - loss: 3.9760e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 4.0983 - val_loss: 3.7913e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.8385
# Epoch 30/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 125ms/step - loss: 3.7481e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 4.6011 - val_loss: 3.5899e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.9812
# Epoch 31/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - loss: 3.5777e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.0265 - val_loss: 3.4160e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 4.3606
# Epoch 32/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 25s 116ms/step - loss: 3.3362e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 4.0867 - val_loss: 3.1763e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.8623
# Epoch 33/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 103ms/step - loss: 3.1687e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.1674 - val_loss: 3.0459e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.6513
# Epoch 34/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 27s 112ms/step - loss: 3.0252e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 4.0653 - val_loss: 2.8641e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.1529
# Epoch 35/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 26s 119ms/step - loss: 2.8247e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.0126 - val_loss: 2.7659e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 4.9401
# Epoch 36/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 77ms/step - loss: 2.6574e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 5.5415 - val_loss: 2.5041e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.6305
# Epoch 37/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 26s 109ms/step - loss: 2.4860e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.8147 - val_loss: 2.3530e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.5867
# Epoch 38/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 27s 123ms/step - loss: 2.3651e-04 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.2467 - val_loss: 2.3632e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 5.1672
# Epoch 39/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 98ms/step - loss: 2.2023e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.6288 - val_loss: 2.0982e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.9533
# Epoch 40/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 115ms/step - loss: 2.0892e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.0883 - val_loss: 2.0308e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.9518
# Epoch 41/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 96ms/step - loss: 2.0012e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.2125 - val_loss: 1.8588e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.3870
# Epoch 42/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 110ms/step - loss: 1.8683e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.2736 - val_loss: 1.8553e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 4.4906
# Epoch 43/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 84ms/step - loss: 1.7415e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.4394 - val_loss: 1.6303e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.3158
# Epoch 44/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - loss: 1.6401e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.4082 - val_loss: 1.6057e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.4760
# Epoch 45/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 74ms/step - loss: 1.6467e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.5923 - val_loss: 1.4548e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.3128
# Epoch 46/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 94ms/step - loss: 1.4753e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.5884 - val_loss: 1.3823e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.3571
# Epoch 47/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 16s 81ms/step - loss: 1.4058e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.0759 - val_loss: 1.4556e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 4.0479
# Epoch 48/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 78ms/step - loss: 1.3779e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 5.1835 - val_loss: 1.2240e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.2912
# Epoch 49/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - loss: 1.2333e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.6073 - val_loss: 1.1831e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.1802
# Epoch 50/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 1.1838e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.5660 - val_loss: 1.1160e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.8155
# Epoch 51/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 76ms/step - loss: 1.1302e-04 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.9350 - val_loss: 1.1304e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 4.3505
# Epoch 52/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 78ms/step - loss: 1.0684e-04 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.6114 - val_loss: 1.1767e-04 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 6.9182
# Epoch 53/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 59ms/step - loss: 1.0551e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 3.5140 - val_loss: 9.6832e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.3273
# Epoch 54/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 78ms/step - loss: 9.8638e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.2141 - val_loss: 1.0092e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 3.6620
# Epoch 55/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - loss: 9.8612e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 3.9086 - val_loss: 8.7105e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 4.4813
# Epoch 56/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - loss: 9.0511e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.3486 - val_loss: 8.7811e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.0545
# Epoch 57/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 8.9767e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.7025 - val_loss: 8.2706e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.2419
# Epoch 58/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - loss: 8.3881e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.1654 - val_loss: 8.2319e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.8352
# Epoch 59/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 8.6223e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.3096 - val_loss: 7.9778e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.2856
# Epoch 60/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - loss: 7.8989e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.7758 - val_loss: 8.7004e-05 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 3.7986
# Epoch 61/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 73ms/step - loss: 7.6646e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 5.2965 - val_loss: 7.4175e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.5208
# Epoch 62/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - loss: 7.7496e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.8962 - val_loss: 7.3420e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.3744
# Epoch 63/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 7.3106e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.3778 - val_loss: 6.9911e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.3390
# Epoch 64/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - loss: 7.3754e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 3.1467 - val_loss: 6.4265e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 4.0608
# Epoch 65/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 6.9963e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.7000 - val_loss: 6.4906e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.8785
# Epoch 66/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 6.7440e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.0594 - val_loss: 8.4452e-05 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 3.7515
# Epoch 67/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - loss: 7.8839e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 3.8551 - val_loss: 6.1235e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 5.1596
# Epoch 68/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 70ms/step - loss: 6.5329e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.6598 - val_loss: 5.9769e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.3993
# Epoch 69/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - loss: 6.8394e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 3.5409 - val_loss: 6.1015e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.3214
# Epoch 70/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 6.7324e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.6678 - val_loss: 5.7377e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.2220
# Epoch 71/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - loss: 6.2440e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.9907 - val_loss: 7.0487e-05 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 3.9690
# Epoch 72/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - loss: 6.6917e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 4.4876 - val_loss: 5.6558e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.5524
# Epoch 73/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - loss: 5.9794e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.3740 - val_loss: 5.6859e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.9287
# Epoch 74/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - loss: 5.9570e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.4007 - val_loss: 5.3807e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.8867
# Epoch 75/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 6.0758e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.3255 - val_loss: 6.3953e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 4.6914
# Epoch 76/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 6.0290e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.9344 - val_loss: 5.9285e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.1928
# Epoch 77/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - loss: 5.9088e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 3.7787 - val_loss: 6.1750e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.2581
# Epoch 78/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - loss: 6.6765e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.5513 - val_loss: 5.0407e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.5530
# Epoch 79/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 5.4871e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.8541 - val_loss: 9.4003e-05 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 6.7711
# Epoch 80/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - loss: 5.5855e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.2738 - val_loss: 4.9115e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.8669
# Epoch 81/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 5.7045e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.6348 - val_loss: 4.9335e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.2932
# Epoch 82/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 5.3109e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.5409 - val_loss: 4.9821e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.1456
# Epoch 83/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - loss: 5.4026e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.3305 - val_loss: 4.6914e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 4.1043
# Epoch 84/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 5.4341e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.3002 - val_loss: 7.7743e-05 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 7.2319
# Epoch 85/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 6.6976e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 5.5123 - val_loss: 4.7299e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.3534
# Epoch 86/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 5.1438e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.0697 - val_loss: 4.7478e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 4.1475
# Epoch 87/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - loss: 5.1626e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 5.3167 - val_loss: 4.8402e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.8854
# Epoch 88/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 5.6623e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 4.4265 - val_loss: 4.8959e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 5.0502
# Epoch 89/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - loss: 4.9770e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.1192 - val_loss: 5.2874e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 6.0499
# Epoch 90/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - loss: 4.9399e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.7661 - val_loss: 5.2248e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 4.8840
# Epoch 91/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 4.7885e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.1522 - val_loss: 4.4767e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 5.0267
# Epoch 92/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 5.3378e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.1967 - val_loss: 4.8601e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.1513
# Epoch 93/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 4.9472e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 5.1984 - val_loss: 4.7128e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.5529
# Epoch 94/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - loss: 5.0427e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.0070 - val_loss: 4.3963e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.1552
# Epoch 95/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - loss: 5.0599e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.4266 - val_loss: 4.2421e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.9672
# Epoch 96/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - loss: 4.4108e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.9001 - val_loss: 4.9187e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.3211
# Epoch 97/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - loss: 5.1595e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 4.1402 - val_loss: 5.6255e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 4.1130
# Epoch 98/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - loss: 5.2455e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.6520 - val_loss: 4.4929e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.5339
# Epoch 99/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - loss: 4.9670e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 3.7377 - val_loss: 4.1764e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.4090
# Epoch 100/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 4.8683e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.9099 - val_loss: 4.1586e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.7683
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_21664\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_21664\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[4012 4574]
#  [4506 4265]]

# %%
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_val_prepared,y_val_predicted)
# Out:
# your profit is [50701.35]
