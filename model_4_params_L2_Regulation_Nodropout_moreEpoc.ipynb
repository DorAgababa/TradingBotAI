# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['next_5_min']
    x = data.drop('next_5_min')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.781022 ┆ -0.780106 ┆ -0.779407 ┆ -0.274536 │
# │ -0.779862 ┆ -0.780807 ┆ -0.780042 ┆ -0.297566 │
# │ -0.78201  ┆ -0.782142 ┆ -0.780891 ┆ -0.467761 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.779856    │
# │ -0.782004    │
# │ -0.778978    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=75
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (92100, 4)
# y_train is (92100, 1)
# x_train_prepared is (81048, 10, 4)
# y_train_prepared is (81048, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.0005, 
    epochs=100
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - loss: 0.2657 - mean_absolute_error: 0.2803 - mean_absolute_percentage_error: 74.4388 - val_loss: 0.0119 - val_mean_absolute_error: 0.0201 - val_mean_absolute_percentage_error: 19.5447
# Epoch 2/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 61ms/step - loss: 0.0115 - mean_absolute_error: 0.0203 - mean_absolute_percentage_error: 15.6211 - val_loss: 0.0099 - val_mean_absolute_error: 0.0098 - val_mean_absolute_percentage_error: 12.8110
# Epoch 3/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 71ms/step - loss: 0.0096 - mean_absolute_error: 0.0085 - mean_absolute_percentage_error: 14.5769 - val_loss: 0.0088 - val_mean_absolute_error: 0.0060 - val_mean_absolute_percentage_error: 11.5317
# Epoch 4/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - loss: 0.0086 - mean_absolute_error: 0.0057 - mean_absolute_percentage_error: 10.0267 - val_loss: 0.0081 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 10.4337
# Epoch 5/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 112ms/step - loss: 0.0079 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 8.5379 - val_loss: 0.0074 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 10.3304
# Epoch 6/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 86ms/step - loss: 0.0073 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 9.6082 - val_loss: 0.0069 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 9.9187
# Epoch 7/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 99ms/step - loss: 0.0067 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 8.1119 - val_loss: 0.0064 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 8.7045
# Epoch 8/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - loss: 0.0062 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 12.3909 - val_loss: 0.0059 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 9.0282
# Epoch 9/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 79ms/step - loss: 0.0058 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 10.1691 - val_loss: 0.0055 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 8.9758
# Epoch 10/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 17s 94ms/step - loss: 0.0053 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 10.5877 - val_loss: 0.0050 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 7.3480
# Epoch 11/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 89ms/step - loss: 0.0049 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 8.0255 - val_loss: 0.0047 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 8.0150
# Epoch 12/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 117ms/step - loss: 0.0046 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 5.7292 - val_loss: 0.0043 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 5.7782
# Epoch 13/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 92ms/step - loss: 0.0042 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 5.8255 - val_loss: 0.0040 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 6.0362
# Epoch 14/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 122ms/step - loss: 0.0039 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.9010 - val_loss: 0.0036 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.9711
# Epoch 15/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 112ms/step - loss: 0.0036 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 6.0772 - val_loss: 0.0034 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 5.0705
# Epoch 16/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.0033 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 5.0109 - val_loss: 0.0031 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.4421
# Epoch 17/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 26s 141ms/step - loss: 0.0030 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 5.2423 - val_loss: 0.0028 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.9061
# Epoch 18/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 115ms/step - loss: 0.0027 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.1461 - val_loss: 0.0026 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.9747
# Epoch 19/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - loss: 0.0025 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.4547 - val_loss: 0.0023 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.6399
# Epoch 20/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 96ms/step - loss: 0.0023 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.9037 - val_loss: 0.0021 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 4.1266
# Epoch 21/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 25s 115ms/step - loss: 0.0021 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 5.0673 - val_loss: 0.0019 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.4155
# Epoch 22/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 25s 120ms/step - loss: 0.0019 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.9793 - val_loss: 0.0017 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.8800
# Epoch 23/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 0.0017 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.4018 - val_loss: 0.0016 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 3.7974
# Epoch 24/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 119ms/step - loss: 0.0015 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.4641 - val_loss: 0.0014 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.0588
# Epoch 25/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 25s 112ms/step - loss: 0.0014 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.4231 - val_loss: 0.0013 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.4646
# Epoch 26/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 109ms/step - loss: 0.0013 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.3212 - val_loss: 0.0011 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.6942
# Epoch 27/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 104ms/step - loss: 0.0011 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.5931 - val_loss: 0.0010 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.8660
# Epoch 28/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - loss: 0.0010 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.4640 - val_loss: 9.3491e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.9531
# Epoch 29/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 29s 111ms/step - loss: 9.0905e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.0979 - val_loss: 8.3009e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.7649
# Epoch 30/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 76ms/step - loss: 8.1654e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.0119 - val_loss: 7.5453e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 4.2119
# Epoch 31/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 95ms/step - loss: 7.3530e-04 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 4.8965 - val_loss: 6.7026e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.3563
# Epoch 32/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 92ms/step - loss: 6.6016e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.0145 - val_loss: 6.1825e-04 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 5.1047
# Epoch 33/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 85ms/step - loss: 5.9779e-04 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 5.1139 - val_loss: 5.5227e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 5.3473
# Epoch 34/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - loss: 5.4771e-04 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 3.8809 - val_loss: 4.9678e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 4.5887
# Epoch 35/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 76ms/step - loss: 4.9559e-04 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 5.9932 - val_loss: 4.4924e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.5895
# Epoch 36/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - loss: 4.4764e-04 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 3.9345 - val_loss: 4.1197e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.0120
# Epoch 37/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - loss: 4.0433e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.0244 - val_loss: 3.7623e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.4108
# Epoch 38/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 17s 89ms/step - loss: 3.7877e-04 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 4.2682 - val_loss: 3.5828e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 4.3398
# Epoch 39/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 71ms/step - loss: 3.4799e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 3.8916 - val_loss: 3.1998e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.9347
# Epoch 40/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 63ms/step - loss: 3.1782e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 3.6930 - val_loss: 3.0019e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 3.9057
# Epoch 41/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 77ms/step - loss: 2.9462e-04 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 3.4797 - val_loss: 2.7602e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.4735
# Epoch 42/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - loss: 2.7960e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.0577 - val_loss: 2.5362e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.5959
# Epoch 43/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - loss: 2.6307e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 4.5183 - val_loss: 2.9095e-04 - val_mean_absolute_error: 0.0071 - val_mean_absolute_percentage_error: 4.1148
# Epoch 44/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 67ms/step - loss: 2.4498e-04 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 3.7224 - val_loss: 2.4426e-04 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 4.5115
# Epoch 45/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - loss: 2.4336e-04 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 5.8080 - val_loss: 2.1095e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.5901
# Epoch 46/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 73ms/step - loss: 2.1439e-04 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 3.4561 - val_loss: 2.0178e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 4.3252
# Epoch 47/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 2.0169e-04 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 3.9586 - val_loss: 1.9046e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.3135
# Epoch 48/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - loss: 1.9810e-04 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 4.3872 - val_loss: 1.9328e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 3.4616
# Epoch 49/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - loss: 1.8957e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 5.4543 - val_loss: 1.9749e-04 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 5.8295
# Epoch 50/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 1.7902e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.8313 - val_loss: 1.7056e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.9064
# Epoch 51/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 1.7790e-04 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 5.1881 - val_loss: 1.7244e-04 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 5.5251
# Epoch 52/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - loss: 1.6807e-04 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 4.6763 - val_loss: 1.4889e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.8200
# Epoch 53/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - loss: 1.6195e-04 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 5.6139 - val_loss: 1.7850e-04 - val_mean_absolute_error: 0.0060 - val_mean_absolute_percentage_error: 6.8713
# Epoch 54/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - loss: 1.5323e-04 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 4.7343 - val_loss: 1.5848e-04 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 3.3788
# Epoch 55/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 1.4610e-04 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 4.2583 - val_loss: 1.3945e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 4.0644
# Epoch 56/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 1.4109e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 3.9110 - val_loss: 1.3381e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 4.5276
# Epoch 57/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - loss: 1.4358e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 4.2971 - val_loss: 1.3459e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.4659
# Epoch 58/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 1.4116e-04 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 4.3727 - val_loss: 1.2597e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.7448
# Epoch 59/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 51ms/step - loss: 1.4159e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 4.8471 - val_loss: 1.5675e-04 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 7.1804
# Epoch 60/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - loss: 1.4397e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 4.4135 - val_loss: 1.1497e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.3917
# Epoch 61/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - loss: 1.2559e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.6608 - val_loss: 1.1561e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.9735
# Epoch 62/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 1.2239e-04 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 4.6265 - val_loss: 1.2458e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 3.7516
# Epoch 63/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - loss: 1.1594e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.1501 - val_loss: 1.1817e-04 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 4.1510
# Epoch 64/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - loss: 1.1464e-04 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 4.4041 - val_loss: 1.0827e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.4343
# Epoch 65/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 1.1058e-04 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 4.4033 - val_loss: 1.5883e-04 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 7.9412
# Epoch 66/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - loss: 1.3885e-04 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 6.4369 - val_loss: 1.0470e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.6163
# Epoch 67/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 1.0984e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.0576 - val_loss: 1.0704e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 5.1589
# Epoch 68/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 1.1215e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.2548 - val_loss: 1.2416e-04 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 3.9453
# Epoch 69/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - loss: 1.0589e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 6.4121 - val_loss: 9.8986e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.8059
# Epoch 70/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - loss: 1.0364e-04 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 4.6870 - val_loss: 9.8160e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 3.9682
# Epoch 71/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 1.1056e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 4.3339 - val_loss: 9.9706e-05 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 3.3785
# Epoch 72/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 1.2206e-04 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 5.9033 - val_loss: 1.0094e-04 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 4.7170
# Epoch 73/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 1.0598e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 3.6758 - val_loss: 1.0320e-04 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 4.3435
# Epoch 74/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 1.0584e-04 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 4.2693 - val_loss: 8.7762e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.2818
# Epoch 75/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 9.6967e-05 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.5991 - val_loss: 1.0282e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 3.7906
# Epoch 76/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 9.8062e-05 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 5.5861 - val_loss: 3.5839e-04 - val_mean_absolute_error: 0.0110 - val_mean_absolute_percentage_error: 11.3572
# Epoch 77/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 1.4149e-04 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 5.9260 - val_loss: 8.6042e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.1492
# Epoch 78/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 9.1396e-05 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 3.5124 - val_loss: 8.7349e-05 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 3.9324
# Epoch 79/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - loss: 9.6081e-05 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 4.3358 - val_loss: 9.1818e-05 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 6.5968
# Epoch 80/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - loss: 1.0279e-04 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 5.3863 - val_loss: 8.3830e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.5947
# Epoch 81/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 9.4953e-05 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.3070 - val_loss: 8.0675e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.3252
# Epoch 82/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 8.8123e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 3.6624 - val_loss: 8.3924e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.4772
# Epoch 83/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 9.0070e-05 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 4.6015 - val_loss: 7.6413e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.6511
# Epoch 84/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - loss: 9.0502e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 4.2421 - val_loss: 7.9759e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.6832
# Epoch 85/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - loss: 8.5395e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.5633 - val_loss: 1.8377e-04 - val_mean_absolute_error: 0.0071 - val_mean_absolute_percentage_error: 4.3791
# Epoch 86/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - loss: 1.0264e-04 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 5.3117 - val_loss: 7.8527e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 5.0429
# Epoch 87/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 8.1301e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.1675 - val_loss: 7.4616e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.3463
# Epoch 88/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 8.4577e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 3.8699 - val_loss: 9.9048e-05 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 5.7630
# Epoch 89/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - loss: 9.3888e-05 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 7.7246 - val_loss: 7.4974e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.9783
# Epoch 90/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 8.8401e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 5.9224 - val_loss: 8.8937e-05 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 4.3232
# Epoch 91/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - loss: 8.5958e-05 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 4.5418 - val_loss: 1.2988e-04 - val_mean_absolute_error: 0.0078 - val_mean_absolute_percentage_error: 7.4421
# Epoch 92/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - loss: 8.7763e-05 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 5.2043 - val_loss: 7.0649e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 5.0706
# Epoch 93/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - loss: 8.8402e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 4.7045 - val_loss: 7.3398e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.2752
# Epoch 94/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - loss: 8.2243e-05 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 4.4111 - val_loss: 6.6204e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.7255
# Epoch 95/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 7.9482e-05 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 4.0610 - val_loss: 6.8370e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 5.9445
# Epoch 96/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 8.9619e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 4.4922 - val_loss: 9.7067e-05 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 3.8132
# Epoch 97/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - loss: 9.9418e-05 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 5.4529 - val_loss: 7.3881e-05 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 3.7292
# Epoch 98/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 7.4656e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 5.3228 - val_loss: 7.2040e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 4.1858
# Epoch 99/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 8.2415e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 4.5395 - val_loss: 6.4372e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.7606
# Epoch 100/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - loss: 8.1919e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 4.9588 - val_loss: 7.2230e-05 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 4.2889
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_13484\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_13484\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[4036 4550]
#  [4559 4212]]
