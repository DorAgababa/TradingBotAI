# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['next_5_min']
    x = data.drop('next_5_min')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.998162 ┆ -0.99737  ┆ -0.997994 ┆ 0.166266  │
# │ -0.998131 ┆ -0.99739  ┆ -0.997658 ┆ 0.054219  │
# │ -0.999289 ┆ -0.998367 ┆ -0.998081 ┆ -0.120579 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.996348    │
# │ -1.000842    │
# │ -0.99807     │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=75
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (92100, 4)
# y_train is (92100, 1)
# x_train_prepared is (81048, 10, 4)
# y_train_prepared is (81048, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=150, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.0005, 
    epochs=100
)
# Out:
# Epoch 1/100
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3013 - mean_absolute_error: 0.3066 - mean_absolute_percentage_error: 65.2834 - val_loss: 0.0130 - val_mean_absolute_error: 0.0212 - val_mean_absolute_percentage_error: 10.1763
# Epoch 2/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0126 - mean_absolute_error: 0.0192 - mean_absolute_percentage_error: 19.5144 - val_loss: 0.0115 - val_mean_absolute_error: 0.0163 - val_mean_absolute_percentage_error: 9.4888
# Epoch 3/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0117 - mean_absolute_error: 0.0149 - mean_absolute_percentage_error: 10.9704 - val_loss: 0.0105 - val_mean_absolute_error: 0.0131 - val_mean_absolute_percentage_error: 8.2228
# Epoch 4/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0103 - mean_absolute_error: 0.0111 - mean_absolute_percentage_error: 9.5414 - val_loss: 0.0098 - val_mean_absolute_error: 0.0102 - val_mean_absolute_percentage_error: 6.5602
# Epoch 5/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0096 - mean_absolute_error: 0.0090 - mean_absolute_percentage_error: 6.7606 - val_loss: 0.0092 - val_mean_absolute_error: 0.0084 - val_mean_absolute_percentage_error: 5.4045
# Epoch 6/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0090 - mean_absolute_error: 0.0072 - mean_absolute_percentage_error: 6.0083 - val_loss: 0.0086 - val_mean_absolute_error: 0.0069 - val_mean_absolute_percentage_error: 4.4030
# Epoch 7/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0085 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 8.9448 - val_loss: 0.0081 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 3.8535
# Epoch 8/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0080 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 4.6518 - val_loss: 0.0076 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 3.3075
# Epoch 9/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0075 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 4.1398 - val_loss: 0.0072 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 3.7595
# Epoch 10/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0071 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 5.2034 - val_loss: 0.0067 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 2.9384
# Epoch 11/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0066 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 4.0134 - val_loss: 0.0063 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 2.8546
# Epoch 12/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0062 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 4.8051 - val_loss: 0.0059 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 2.8420
# Epoch 13/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0058 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.5262 - val_loss: 0.0055 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 2.9799
# Epoch 14/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0054 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.9464 - val_loss: 0.0052 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 2.7962
# Epoch 15/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0051 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 4.1135 - val_loss: 0.0048 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 2.6521
# Epoch 16/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0047 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.5260 - val_loss: 0.0045 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 2.4383
# Epoch 17/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 5.0981 - val_loss: 0.0042 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 3.1975
# Epoch 18/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0041 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 3.6892 - val_loss: 0.0039 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 2.2111
# Epoch 19/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0038 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.5558 - val_loss: 0.0036 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 2.2300
# Epoch 20/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0035 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.6311 - val_loss: 0.0033 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 2.1351
# Epoch 21/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0033 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 4.4250 - val_loss: 0.0031 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 2.0385
# Epoch 22/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0030 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 4.0003 - val_loss: 0.0028 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.8259
# Epoch 23/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.9326 - val_loss: 0.0026 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.0682
# Epoch 24/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.8354 - val_loss: 0.0024 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.8716
# Epoch 25/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0023 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.8668 - val_loss: 0.0022 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.7721
# Epoch 26/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.0350 - val_loss: 0.0020 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.9295
# Epoch 27/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.6416 - val_loss: 0.0018 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 1.5164
# Epoch 28/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.7330 - val_loss: 0.0016 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.3851
# Epoch 29/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0016 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3138 - val_loss: 0.0015 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 1.5323
# Epoch 30/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0014 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.5098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 2.1509
# Epoch 31/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0013 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.0150 - val_loss: 0.0012 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 1.3390
# Epoch 32/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4538 - val_loss: 0.0011 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.3795
# Epoch 33/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0011 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.9028 - val_loss: 9.7542e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 1.5052
# Epoch 34/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.5276e-04 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 2.1548 - val_loss: 8.7254e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 1.3395
# Epoch 35/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.4795e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.8524 - val_loss: 7.8681e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 1.6238
# Epoch 36/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 7.6305e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 2.1214 - val_loss: 7.1197e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 1.3820
# Epoch 37/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.8108e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.3020 - val_loss: 6.3089e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 1.2981
# Epoch 38/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.1048e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.9585 - val_loss: 5.5949e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.6648
# Epoch 39/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.4889e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.2243 - val_loss: 5.0151e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.4823
# Epoch 40/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.0009e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 2.1509 - val_loss: 4.6186e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 1.8362
# Epoch 41/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 4.4901e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.0522 - val_loss: 4.1738e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 1.6464
# Epoch 42/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 4.0433e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.1582 - val_loss: 3.8606e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 1.3082
# Epoch 43/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.7156e-04 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 2.5505 - val_loss: 3.4086e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.3636
# Epoch 44/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 3.3103e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4648 - val_loss: 3.0449e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.1238
# Epoch 45/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.1004e-04 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 2.2403 - val_loss: 2.8164e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.1888
# Epoch 46/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.7696e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.7442 - val_loss: 2.5572e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.1454
# Epoch 47/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.5576e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.4262 - val_loss: 2.8700e-04 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 2.1616
# Epoch 48/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 4.7457e-04 - mean_absolute_error: 0.0084 - mean_absolute_percentage_error: 3.5414 - val_loss: 2.2793e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.8766
# Epoch 49/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 2.2271e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.8070 - val_loss: 2.1058e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.3132
# Epoch 50/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 2.0994e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 2.9469 - val_loss: 2.0400e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 1.4676
# Epoch 51/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.9958e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.2458 - val_loss: 1.8752e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.5287
# Epoch 52/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.8867e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.6165 - val_loss: 1.7799e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.1172
# Epoch 53/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.8091e-04 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.0561 - val_loss: 1.6682e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 0.9486
# Epoch 54/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.6888e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3475 - val_loss: 1.6222e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.4801
# Epoch 55/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.6180e-04 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.1874 - val_loss: 1.4967e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.1452
# Epoch 56/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.5348e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.3881 - val_loss: 1.4513e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.2464
# Epoch 57/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.5699e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 2.6110 - val_loss: 1.3861e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.2490
# Epoch 58/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.4402e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.5099 - val_loss: 1.3483e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 1.1645
# Epoch 59/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.3188e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.1484 - val_loss: 1.2981e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 1.6307
# Epoch 60/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.2985e-04 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.0412 - val_loss: 1.4287e-04 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 3.3562
# Epoch 61/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.3254e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 2.5191 - val_loss: 1.1233e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.4479
# Epoch 62/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.1560e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4580 - val_loss: 1.1934e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 2.2145
# Epoch 63/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.4672e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 2.4958 - val_loss: 1.1792e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 1.5031
# Epoch 64/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.1034e-04 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.0738 - val_loss: 1.0075e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.1147
# Epoch 65/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.0548e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.0527 - val_loss: 1.4917e-04 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 2.8995
# Epoch 66/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.0688e-04 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 3.3695 - val_loss: 9.4976e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.1534
# Epoch 67/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.9053e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.1044 - val_loss: 9.6453e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 2.0082
# Epoch 68/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 1.0573e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 2.2948 - val_loss: 8.7496e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.1523
# Epoch 69/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 9.8371e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 6.9463 - val_loss: 8.9278e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 0.9087
# Epoch 70/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.6192e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 2.4845 - val_loss: 8.3980e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.5628
# Epoch 71/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.7614e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.0160 - val_loss: 7.9119e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.1006
# Epoch 72/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.7355e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 4.7084 - val_loss: 1.6940e-04 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 4.0740
# Epoch 73/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.0172e-04 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 2.7646 - val_loss: 7.4561e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 0.9680
# Epoch 74/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.1616e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 1.7916 - val_loss: 7.9757e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 1.0444
# Epoch 75/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.0545e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.3679 - val_loss: 7.2498e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.3585
# Epoch 76/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.3602e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.1478 - val_loss: 8.3023e-05 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 1.5566
# Epoch 77/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.5674e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 2.8438 - val_loss: 8.1312e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 1.1023
# Epoch 78/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 9.0619e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 3.1311 - val_loss: 8.1198e-05 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 1.5012
# Epoch 79/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.8403e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 2.3350 - val_loss: 9.1777e-05 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 1.1821
# Epoch 80/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.1476e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 2.4797 - val_loss: 6.5050e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.0830
# Epoch 81/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.4969e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 2.1617 - val_loss: 6.2291e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3933
# Epoch 82/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.8442e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.0764 - val_loss: 6.2566e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.6631
# Epoch 83/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.9147e-05 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 2.3684 - val_loss: 6.2645e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 1.2152
# Epoch 84/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.9880e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.0539 - val_loss: 1.3212e-04 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 1.6767
# Epoch 85/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.8664e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.4527 - val_loss: 5.8878e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 0.9896
# Epoch 86/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.2712e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4365 - val_loss: 6.0476e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 2.0919
# Epoch 87/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.4456e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 2.3673 - val_loss: 5.5086e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.1461
# Epoch 88/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.0681e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.3930 - val_loss: 6.1965e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 1.4487
# Epoch 89/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.6535e-05 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 2.7829 - val_loss: 5.8287e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.3811
# Epoch 90/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 6.8641e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 2.1028 - val_loss: 7.3278e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 1.9438
# Epoch 91/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 7.0476e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 2.9874 - val_loss: 6.1301e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 1.4500
# Epoch 92/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.7239e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3140 - val_loss: 6.4340e-05 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 2.0851
# Epoch 93/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.8897e-05 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 3.6067 - val_loss: 5.7587e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 1.5892
# Epoch 94/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.5738e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.0379 - val_loss: 5.0183e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.3337
# Epoch 95/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.3579e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.9416 - val_loss: 6.3145e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 2.6189
# Epoch 96/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 1.0243e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 3.2563 - val_loss: 4.7797e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.1690
# Epoch 97/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 5.3489e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.8435 - val_loss: 6.8324e-05 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 1.8066
# Epoch 98/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.0295e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 3.1987 - val_loss: 8.3933e-05 - val_mean_absolute_error: 0.0053 - val_mean_absolute_percentage_error: 1.9653
# Epoch 99/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.7561e-05 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 2.3780 - val_loss: 4.8503e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 1.2035
# Epoch 100/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 5.5574e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.7528 - val_loss: 4.9058e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.3354
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# Confusion Matrix:
# [[6109 2462]
#  [2411 6375]]
# C:\Users\David\AppData\Local\Temp\ipykernel_2292\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_2292\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
