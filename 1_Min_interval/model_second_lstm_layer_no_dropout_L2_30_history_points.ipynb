# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.968311 ┆ -0.961899 ┆ -0.959462 ┆ -0.744139 │
# │ -0.968109 ┆ -0.963969 ┆ -0.960285 ┆ -1.140859 │
# │ -0.966712 ┆ -0.964883 ┆ -0.960897 ┆ -1.237162 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.968103    │
# │ -0.966707    │
# │ -0.965175    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1),return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 30
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (424888, 30, 4)
# y_train_prepared is (424888, 1)

# %%
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=25, 
    regular_layer1_size=64, 
    regular_layer2_size=0,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=30, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.00005, 
    epochs=80
)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 34s 38ms/step - loss: 0.3679 - mean_absolute_error: 0.3747 - mean_absolute_percentage_error: 68.9802 - val_loss: 0.0216 - val_mean_absolute_error: 0.0151 - val_mean_absolute_percentage_error: 13.7469
# Epoch 2/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0209 - mean_absolute_error: 0.0118 - mean_absolute_percentage_error: 9.7552 - val_loss: 0.0192 - val_mean_absolute_error: 0.0084 - val_mean_absolute_percentage_error: 6.1330
# Epoch 3/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0187 - mean_absolute_error: 0.0075 - mean_absolute_percentage_error: 7.1693 - val_loss: 0.0171 - val_mean_absolute_error: 0.0062 - val_mean_absolute_percentage_error: 7.0082
# Epoch 4/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0166 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 6.9971 - val_loss: 0.0151 - val_mean_absolute_error: 0.0053 - val_mean_absolute_percentage_error: 7.1774
# Epoch 5/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0146 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 5.7469 - val_loss: 0.0131 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 5.9882
# Epoch 6/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0127 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 5.1215 - val_loss: 0.0112 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 5.2715
# Epoch 7/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0108 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.1021 - val_loss: 0.0094 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 4.6298
# Epoch 8/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 0.0090 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 3.3854 - val_loss: 0.0077 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.9886
# Epoch 9/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0073 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.2894 - val_loss: 0.0062 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.0866
# Epoch 10/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0058 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 3.0632 - val_loss: 0.0048 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.3648
# Epoch 11/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0044 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.7604 - val_loss: 0.0036 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.7778
# Epoch 12/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0033 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3155 - val_loss: 0.0026 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.4880
# Epoch 13/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0024 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.5118 - val_loss: 0.0019 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 4.4250
# Epoch 14/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 0.0017 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4474 - val_loss: 0.0014 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.5182
# Epoch 15/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 0.0013 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3931 - val_loss: 0.0010 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.7416
# Epoch 16/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 9.5216e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.2967 - val_loss: 7.9673e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.5094
# Epoch 17/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.4540e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.1486 - val_loss: 6.4352e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 2.6766
# Epoch 18/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 6.0481e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3801 - val_loss: 5.3669e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 2.4216
# Epoch 19/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 37ms/step - loss: 5.0861e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4990 - val_loss: 4.6357e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.0929
# Epoch 20/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 37ms/step - loss: 4.3689e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.5919 - val_loss: 4.0683e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 3.0124
# Epoch 21/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 36ms/step - loss: 3.7996e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.7535 - val_loss: 3.6070e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 2.0039
# Epoch 22/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 37ms/step - loss: 3.3537e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.2633 - val_loss: 3.2742e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 1.8350
# Epoch 23/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 2.9997e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.1897 - val_loss: 2.9215e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.8378
# Epoch 24/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 36ms/step - loss: 2.6997e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4768 - val_loss: 2.6726e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 2.0487
# Epoch 25/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 37ms/step - loss: 2.4540e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.6276 - val_loss: 2.4728e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 2.2184
# Epoch 26/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 37ms/step - loss: 2.2409e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3128 - val_loss: 2.3214e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 2.8414
# Epoch 27/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 2.0598e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4680 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.1453
# Epoch 28/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 1.9097e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.1896 - val_loss: 1.9873e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.2950
# Epoch 29/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.7785e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3508 - val_loss: 1.8915e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.9241
# Epoch 30/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.6782e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.2046 - val_loss: 1.7619e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 3.8281
# Epoch 31/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.5771e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3547 - val_loss: 1.7496e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.7987
# Epoch 32/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.4960e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.2477 - val_loss: 1.6063e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 4.7099
# Epoch 33/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.4255e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.2150 - val_loss: 1.5794e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.4147
# Epoch 34/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.3638e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.6004 - val_loss: 1.5326e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.1727
# Epoch 35/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.3027e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.2063 - val_loss: 1.4514e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.3726
# Epoch 36/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.2506e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.8675 - val_loss: 1.3660e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.6329
# Epoch 37/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.2010e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.6669 - val_loss: 1.3238e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.2638
# Epoch 38/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 1.4180e-04 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 2.8479 - val_loss: 1.3907e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.9211
# Epoch 39/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.1626e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3415 - val_loss: 1.3530e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.8777
# Epoch 40/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.1237e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.7660 - val_loss: 1.3080e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.7185
# Epoch 41/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.0925e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.5400 - val_loss: 1.2887e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 4.0131
# Epoch 42/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.0565e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.5680 - val_loss: 1.2812e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.3799
# Epoch 43/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 1.0373e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4519 - val_loss: 1.2412e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 4.1471
# Epoch 44/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 9.9885e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4019 - val_loss: 1.2128e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.8208
# Epoch 45/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 9.7791e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3466 - val_loss: 1.1677e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.4022
# Epoch 46/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 9.5531e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4122 - val_loss: 1.1125e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 3.7669
# Epoch 47/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 9.2754e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3417 - val_loss: 1.0909e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 3.3320
# Epoch 48/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 9.1257e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4221 - val_loss: 1.1119e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.7573
# Epoch 49/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 9.0199e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3973 - val_loss: 1.0644e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.5439
# Epoch 50/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 8.7468e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.2478 - val_loss: 1.0470e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.9114
# Epoch 51/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 8.5670e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.7698 - val_loss: 1.0321e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.6757
# Epoch 52/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 8.3968e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.2229 - val_loss: 1.0209e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.6945
# Epoch 53/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 30s 37ms/step - loss: 8.2425e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.5091 - val_loss: 1.0390e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.0673
# Epoch 54/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 8.1090e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3308 - val_loss: 1.0220e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.6391
# Epoch 55/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.9381e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.5490 - val_loss: 9.4912e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.1716
# Epoch 56/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.7715e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3108 - val_loss: 9.6311e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.4633
# Epoch 57/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.7711e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4946 - val_loss: 9.4591e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.9556
# Epoch 58/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 32s 38ms/step - loss: 7.5374e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4243 - val_loss: 9.2728e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 3.1220
# Epoch 59/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 7.4165e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3624 - val_loss: 9.1780e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.8775
# Epoch 60/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.3782e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4399 - val_loss: 9.5389e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 2.5819
# Epoch 61/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.1636e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.5359 - val_loss: 8.9236e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.4985
# Epoch 62/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.0975e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.5180 - val_loss: 9.0759e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 2.5617
# Epoch 63/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 7.0562e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3406 - val_loss: 8.6407e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 2.4693
# Epoch 64/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 6.9590e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.1830 - val_loss: 8.4448e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.7171
# Epoch 65/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 32s 38ms/step - loss: 6.7488e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.3308 - val_loss: 8.8602e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.0026
# Epoch 66/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 6.7793e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.3954 - val_loss: 8.6342e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 2.8351
# Epoch 67/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 6.6742e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.2842 - val_loss: 8.8587e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.3669
# Epoch 68/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 6.6822e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.4398 - val_loss: 9.1469e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.5190
# Epoch 69/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 6.4898e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.7114 - val_loss: 8.4826e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 4.1603
# Epoch 70/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 6.4428e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.1694 - val_loss: 8.1203e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.8048
# Epoch 71/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 6.4110e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.1061 - val_loss: 8.0841e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 2.6538
# Epoch 72/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 6.2808e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.2512 - val_loss: 8.0190e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.7910
# Epoch 73/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 6.2861e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.0554 - val_loss: 8.1577e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 2.8736
# Epoch 74/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 6.1065e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.3871 - val_loss: 8.4908e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.0012
# Epoch 75/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 6.1809e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3761 - val_loss: 8.0001e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 2.9314
# Epoch 76/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 6.0481e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.6749 - val_loss: 7.9377e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 2.7925
# Epoch 77/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 6.0659e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.1461 - val_loss: 7.7743e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 2.8417
# Epoch 78/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 32s 38ms/step - loss: 5.9383e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.5355 - val_loss: 7.7747e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.2895
# Epoch 79/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 5.9350e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3141 - val_loss: 7.5102e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.6257
# Epoch 80/80
# 830/830 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - loss: 5.7915e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.3392 - val_loss: 7.9610e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 2.8287
# 2844/2844 ━━━━━━━━━━━━━━━━━━━━ 43s 15ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# /tmp/ipykernel_36/2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# /tmp/ipykernel_36/2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[22325 23280]
#  [22423 22969]]

# %%
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_val_prepared,y_val_predicted)
# Out:
# your profit is [48809.45]
