# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬──────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪══════════╡
# │ -0.826309 ┆ -0.841511 ┆ -0.847228 ┆ 1.866119 │
# │ -0.827013 ┆ -0.836676 ┆ -0.845299 ┆ 2.815468 │
# │ -0.823052 ┆ -0.832132 ┆ -0.843176 ┆ 3.606465 │
# └───────────┴───────────┴───────────┴──────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.827027    │
# │ -0.823065    │
# │ -0.822361    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (449448, 10, 4)
# y_train_prepared is (449448, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=25, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.00005, 
    epochs=100
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step - loss: 0.1443 - mean_absolute_error: 0.1526 - mean_absolute_percentage_error: 40.7800 - val_loss: 0.0061 - val_mean_absolute_error: 0.0074 - val_mean_absolute_percentage_error: 40.8694
# Epoch 2/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - loss: 0.0056 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 9.7058 - val_loss: 0.0044 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 22.8233
# Epoch 3/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - loss: 0.0040 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 6.8644 - val_loss: 0.0031 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 15.3510
# Epoch 4/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - loss: 0.0028 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.0845 - val_loss: 0.0021 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 9.6583
# Epoch 5/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - loss: 0.0019 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 6.3978 - val_loss: 0.0014 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 9.3338
# Epoch 6/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - loss: 0.0012 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 5.4552 - val_loss: 8.4351e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 5.9897
# Epoch 7/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - loss: 7.4881e-04 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 3.1747 - val_loss: 5.2606e-04 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 8.4247
# Epoch 8/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 4.6252e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 3.1813 - val_loss: 3.3941e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 10.3388
# Epoch 9/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 3.0153e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.9998 - val_loss: 2.3064e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 10.4121
# Epoch 10/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2.0943e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.6567 - val_loss: 1.6267e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 9.3437
# Epoch 11/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 1.5812e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.7237 - val_loss: 1.2482e-04 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.3598
# Epoch 12/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 1.2702e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.8738 - val_loss: 1.1137e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 11.6604
# Epoch 13/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 1.0500e-04 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.7181 - val_loss: 8.7524e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 8.5175
# Epoch 14/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 9.0498e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 3.8569 - val_loss: 7.5868e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 8.8648
# Epoch 15/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - loss: 8.0157e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 5.1564 - val_loss: 7.5532e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 12.0567
# Epoch 16/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 7.2865e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.3151 - val_loss: 6.3539e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 9.5148
# Epoch 17/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 6.5150e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.1334 - val_loss: 6.4861e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 15.4876
# Epoch 18/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 6.2628e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.6940 - val_loss: 6.3183e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 8.2348
# Epoch 19/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - loss: 5.9494e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.3901 - val_loss: 4.6228e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 9.9612
# Epoch 20/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 5.3179e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 3.4850 - val_loss: 5.0231e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 14.7545
# Epoch 21/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 5.1398e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 4.4651 - val_loss: 4.1463e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 11.8124
# Epoch 22/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 5.0884e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.5859 - val_loss: 3.8742e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 10.1757
# Epoch 23/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 4.6388e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.3349 - val_loss: 4.3426e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 15.8910
# Epoch 24/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - loss: 4.5453e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.4423 - val_loss: 3.7402e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 8.7137
# Epoch 25/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 4.2796e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 6.8793 - val_loss: 3.9453e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 7.9586
# Epoch 26/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 4.2483e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.5751 - val_loss: 3.9235e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 17.4116
# Epoch 27/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - loss: 4.2714e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 6.0356 - val_loss: 4.4797e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 14.7197
# Epoch 28/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 3.9489e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.9306 - val_loss: 3.2993e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 7.8327
# Epoch 29/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - loss: 3.9539e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.6410 - val_loss: 2.9644e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 9.3976
# Epoch 30/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 4.0471e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.4510 - val_loss: 2.8313e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 11.2382
# Epoch 31/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 5.2933e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 2.9397 - val_loss: 3.9738e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 14.5153
# Epoch 32/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 4.0476e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.4123 - val_loss: 2.9042e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 8.6131
# Epoch 33/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 3.5578e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.2505 - val_loss: 2.9094e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 13.1988
# Epoch 34/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 3.3245e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.4836 - val_loss: 3.0439e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 10.8560
# Epoch 35/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 3.6443e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.1011 - val_loss: 2.5634e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 10.8274
# Epoch 36/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 4.0028e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.2115 - val_loss: 2.8758e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 15.0931
# Epoch 37/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 3.5906e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.9351 - val_loss: 2.7286e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 11.9734
# Epoch 38/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - loss: 3.0727e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 3.3923 - val_loss: 2.4692e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 10.3799
# Epoch 39/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 3.5564e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.8349 - val_loss: 4.0029e-05 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 11.5844
# Epoch 40/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 22s 24ms/step - loss: 3.7699e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 2.6868 - val_loss: 2.8708e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 7.7180
# Epoch 41/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 3.3614e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.6422 - val_loss: 4.8434e-05 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 17.2594
# Epoch 42/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.0905e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.3957 - val_loss: 3.6567e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 16.1311
# Epoch 43/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.5173e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 3.7517 - val_loss: 2.4166e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 9.4729
# Epoch 44/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.4609e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 4.6305 - val_loss: 2.6540e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 9.6998
# Epoch 45/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.6086e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.8075 - val_loss: 2.3131e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 10.2712
# Epoch 46/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 3.0908e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.6311 - val_loss: 2.5487e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 10.1961
# Epoch 47/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 3.3046e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 6.6547 - val_loss: 4.4166e-05 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 7.6961
# Epoch 48/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 3.2611e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.7456 - val_loss: 2.3846e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 9.2369
# Epoch 49/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.7986e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 2.7633 - val_loss: 3.5744e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 7.6840
# Epoch 50/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 3.3830e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.3960 - val_loss: 9.7604e-05 - val_mean_absolute_error: 0.0057 - val_mean_absolute_percentage_error: 16.8119
# Epoch 51/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 3.3813e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.7535 - val_loss: 2.5670e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 12.9586
# Epoch 52/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 3.4683e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 2.8243 - val_loss: 5.7099e-05 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 23.8099
# Epoch 53/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.8888e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 3.3403 - val_loss: 2.5971e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 9.3962
# Epoch 54/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2.9306e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.4103 - val_loss: 2.3608e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 12.0729
# Epoch 55/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - loss: 2.9994e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.1064 - val_loss: 7.6702e-05 - val_mean_absolute_error: 0.0067 - val_mean_absolute_percentage_error: 25.5541
# Epoch 56/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 4.4126e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.7728 - val_loss: 2.0409e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 9.9010
# Epoch 57/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 2.5586e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 3.0964 - val_loss: 1.0558e-04 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 24.6775
# Epoch 58/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2.9898e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.8416 - val_loss: 2.4897e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 8.7726
# Epoch 59/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 2.8928e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.5205 - val_loss: 1.9400e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 8.6815
# Epoch 60/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.1716e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.6300 - val_loss: 2.2175e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 9.4941
# Epoch 61/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2.9824e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.4670 - val_loss: 2.7445e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 16.2674
# Epoch 62/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.3310e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.1179 - val_loss: 2.7295e-04 - val_mean_absolute_error: 0.0127 - val_mean_absolute_percentage_error: 22.8493
# Epoch 63/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 3.4892e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.1798 - val_loss: 2.2441e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 11.0089
# Epoch 64/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.0417e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 4.9669 - val_loss: 1.9492e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 9.6921
# Epoch 65/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2.9283e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 3.2276 - val_loss: 2.3918e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 7.6999
# Epoch 66/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 3.0006e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.8748 - val_loss: 2.6818e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 8.7708
# Epoch 67/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2.6658e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.2285 - val_loss: 7.3678e-05 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 9.0009
# Epoch 68/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - loss: 6.2442e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.9139 - val_loss: 3.0347e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 11.3910
# Epoch 69/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 2.8314e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 3.1060 - val_loss: 2.6364e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 6.3747
# Epoch 70/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 3.1706e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.5691 - val_loss: 5.2402e-05 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 6.1478
# Epoch 71/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 22s 25ms/step - loss: 3.4094e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.0882 - val_loss: 3.8426e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 10.7676
# Epoch 72/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 3.0678e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 4.6472 - val_loss: 2.5775e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 6.9385
# Epoch 73/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 2.8891e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.6102 - val_loss: 3.0704e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 7.3219
# Epoch 74/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 2.7785e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 3.1746 - val_loss: 2.0168e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 7.3052
# Epoch 75/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 2.6779e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.2343 - val_loss: 1.9313e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 9.5392
# Epoch 76/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 2.6722e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.8307 - val_loss: 2.6806e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 7.0498
# Epoch 77/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 4.2202e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.8068 - val_loss: 1.9390e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 8.0646
# Epoch 78/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 3.2757e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 6.4988 - val_loss: 2.2960e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 15.2967
# Epoch 79/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 3.1047e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 4.6791 - val_loss: 1.8942e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 7.9072
# Epoch 80/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 2.7667e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.2266 - val_loss: 2.0653e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 5.7455
# Epoch 81/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 2.8302e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.3193 - val_loss: 4.6154e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 11.9670
# Epoch 82/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 2.8252e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.6404 - val_loss: 1.9077e-04 - val_mean_absolute_error: 0.0090 - val_mean_absolute_percentage_error: 31.2413
# Epoch 83/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 3.2380e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.2665 - val_loss: 1.9563e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 6.2444
# Epoch 84/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 2.5888e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.6795 - val_loss: 2.1361e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 5.3774
# Epoch 85/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 2.9819e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.8593 - val_loss: 4.6480e-05 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 6.3008
# Epoch 86/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 3.1468e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 4.2513 - val_loss: 2.0594e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 11.6671
# Epoch 87/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 3.1779e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.9082 - val_loss: 2.0018e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 8.0375
# Epoch 88/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - loss: 2.9999e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 3.1396 - val_loss: 2.4109e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 10.5274
# Epoch 89/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 3.3394e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.3880 - val_loss: 1.8889e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 7.2643
# Epoch 90/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 2.5456e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 3.8808 - val_loss: 3.9780e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 16.5850
# Epoch 91/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 3.1064e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 2.9750 - val_loss: 1.9962e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 6.3852
# Epoch 92/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 2.7531e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.7816 - val_loss: 2.4292e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 10.0493
# Epoch 93/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - loss: 3.0331e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.1915 - val_loss: 2.8482e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 6.3117
# Epoch 94/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 2.5959e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.5208 - val_loss: 1.8382e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 11.2360
# Epoch 95/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 2.8350e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.6183 - val_loss: 1.7728e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 9.8036
# Epoch 96/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 2.4812e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.6140 - val_loss: 2.4706e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 15.0708
# Epoch 97/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 23ms/step - loss: 2.7765e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.6028 - val_loss: 2.4431e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 11.1873
# Epoch 98/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 3.0522e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.0390 - val_loss: 2.1272e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 9.1108
# Epoch 99/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 2.7847e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.0413 - val_loss: 2.7558e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 12.9704
# Epoch 100/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - loss: 2.4823e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 3.4116 - val_loss: 3.3688e-05 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 9.2045
# 3009/3009 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_26180\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_26180\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[23893 24342]
#  [23448 24574]]
