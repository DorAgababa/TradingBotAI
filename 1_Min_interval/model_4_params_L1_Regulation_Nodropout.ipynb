# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬──────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪══════════╡
# │ -0.826309 ┆ -0.841511 ┆ -0.847228 ┆ 1.866119 │
# │ -0.827013 ┆ -0.836676 ┆ -0.845299 ┆ 2.815468 │
# │ -0.823052 ┆ -0.832132 ┆ -0.843176 ┆ 3.606465 │
# └───────────┴───────────┴───────────┴──────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.827027    │
# │ -0.823065    │
# │ -0.822361    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (449448, 10, 4)
# y_train_prepared is (449448, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0.0002, 
    L2=0, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=128, 
    learning_rate=0.00005, 
    epochs=50
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.1805 - mean_absolute_error: 0.1306 - mean_absolute_percentage_error: 40.5591 - val_loss: 0.0368 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 24.4197
# Epoch 2/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 0.0314 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 7.1772 - val_loss: 0.0188 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 18.7949
# Epoch 3/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - loss: 0.0162 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 7.2116 - val_loss: 0.0099 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 17.7857
# Epoch 4/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 0.0086 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 6.0312 - val_loss: 0.0053 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 17.8961
# Epoch 5/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 0.0047 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 7.1510 - val_loss: 0.0031 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 17.1801
# Epoch 6/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 0.0028 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 5.5564 - val_loss: 0.0020 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 8.9282
# Epoch 7/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 0.0018 - mean_absolute_error: 0.0060 - mean_absolute_percentage_error: 5.5597 - val_loss: 0.0013 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 22.0111
# Epoch 8/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 5.2531 - val_loss: 0.0014 - val_mean_absolute_error: 0.0169 - val_mean_absolute_percentage_error: 18.2611
# Epoch 9/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 9.7546e-04 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 3.9217 - val_loss: 8.1120e-04 - val_mean_absolute_error: 0.0068 - val_mean_absolute_percentage_error: 8.8963
# Epoch 10/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - loss: 7.6496e-04 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 5.5876 - val_loss: 6.3278e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 11.9159
# Epoch 11/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 6.2455e-04 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 6.6700 - val_loss: 5.3381e-04 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 13.0453
# Epoch 12/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - loss: 5.6977e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 6.2326 - val_loss: 4.3470e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 12.7848
# Epoch 13/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - loss: 5.1156e-04 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 5.5017 - val_loss: 4.1327e-04 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 23.0281
# Epoch 14/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 4.5818e-04 - mean_absolute_error: 0.0062 - mean_absolute_percentage_error: 6.8928 - val_loss: 3.7715e-04 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 12.1586
# Epoch 15/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 4.3405e-04 - mean_absolute_error: 0.0063 - mean_absolute_percentage_error: 6.5496 - val_loss: 4.0877e-04 - val_mean_absolute_error: 0.0077 - val_mean_absolute_percentage_error: 25.8085
# Epoch 16/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 4.8844e-04 - mean_absolute_error: 0.0070 - mean_absolute_percentage_error: 6.3255 - val_loss: 3.7717e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 14.6479
# Epoch 17/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 3.6814e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.4551 - val_loss: 3.2592e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 12.8493
# Epoch 18/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 3.6371e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 4.7589 - val_loss: 3.0581e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 11.3469
# Epoch 19/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 3.5263e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 5.4733 - val_loss: 3.1533e-04 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 11.9385
# Epoch 20/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 3.4552e-04 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 7.7957 - val_loss: 3.1311e-04 - val_mean_absolute_error: 0.0053 - val_mean_absolute_percentage_error: 10.2931
# Epoch 21/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - loss: 3.3140e-04 - mean_absolute_error: 0.0055 - mean_absolute_percentage_error: 5.7588 - val_loss: 3.0320e-04 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 10.7304
# Epoch 22/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 3.5814e-04 - mean_absolute_error: 0.0057 - mean_absolute_percentage_error: 7.5588 - val_loss: 2.8057e-04 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 11.8737
# Epoch 23/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 3.2959e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 6.3648 - val_loss: 3.6586e-04 - val_mean_absolute_error: 0.0093 - val_mean_absolute_percentage_error: 11.9992
# Epoch 24/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 3.2489e-04 - mean_absolute_error: 0.0064 - mean_absolute_percentage_error: 5.9373 - val_loss: 2.5657e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 13.5103
# Epoch 25/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 4.5929e-04 - mean_absolute_error: 0.0069 - mean_absolute_percentage_error: 6.3788 - val_loss: 3.2203e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 13.1907
# Epoch 26/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 3.0943e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 3.6561 - val_loss: 2.6681e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 19.4936
# Epoch 27/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 2.8162e-04 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 6.3687 - val_loss: 2.6644e-04 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 23.6173
# Epoch 28/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 2.8206e-04 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 5.7361 - val_loss: 2.7302e-04 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 14.0644
# Epoch 29/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 2.8087e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 5.3488 - val_loss: 2.3434e-04 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 16.7055
# Epoch 30/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 2.6601e-04 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 5.3706 - val_loss: 2.4929e-04 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 21.2747
# Epoch 31/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 2.9308e-04 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 4.7811 - val_loss: 4.7166e-04 - val_mean_absolute_error: 0.0145 - val_mean_absolute_percentage_error: 50.4073
# Epoch 32/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 14s 16ms/step - loss: 2.8439e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 6.3730 - val_loss: 2.1801e-04 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 15.4054
# Epoch 33/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 2.6860e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 5.7495 - val_loss: 2.3206e-04 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 19.2459
# Epoch 34/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 2.5348e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 5.2839 - val_loss: 2.2900e-04 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 12.8915
# Epoch 35/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 2.7122e-04 - mean_absolute_error: 0.0057 - mean_absolute_percentage_error: 9.0835 - val_loss: 2.1060e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 14.4831
# Epoch 36/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - loss: 2.6176e-04 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 4.6631 - val_loss: 2.2243e-04 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 19.2105
# Epoch 37/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 2.3946e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 7.1207 - val_loss: 2.2588e-04 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 9.5750
# Epoch 38/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 2.4492e-04 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 6.4555 - val_loss: 2.2617e-04 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 13.5323
# Epoch 39/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - loss: 2.1826e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 4.2164 - val_loss: 2.2893e-04 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 25.6302
# Epoch 40/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - loss: 2.2888e-04 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 5.0150 - val_loss: 2.3730e-04 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 17.7516
# Epoch 41/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - loss: 2.6333e-04 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 6.1682 - val_loss: 1.9755e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 15.7790
# Epoch 42/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 31s 36ms/step - loss: 2.2859e-04 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 6.4411 - val_loss: 2.3160e-04 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 12.8612
# Epoch 43/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 33s 38ms/step - loss: 2.2797e-04 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 5.1677 - val_loss: 2.2348e-04 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 11.8058
# Epoch 44/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 40s 46ms/step - loss: 2.3893e-04 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 4.4859 - val_loss: 5.3589e-04 - val_mean_absolute_error: 0.0129 - val_mean_absolute_percentage_error: 40.3592
# Epoch 45/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 40s 45ms/step - loss: 2.6406e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 8.3119 - val_loss: 1.8692e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 12.6208
# Epoch 46/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 39s 45ms/step - loss: 2.2010e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 4.9182 - val_loss: 2.3892e-04 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 20.4770
# Epoch 47/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 36s 41ms/step - loss: 2.1024e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 6.4969 - val_loss: 1.8700e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 13.4432
# Epoch 48/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 35s 40ms/step - loss: 2.2457e-04 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 5.6879 - val_loss: 1.7945e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 14.8286
# Epoch 49/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 36s 40ms/step - loss: 2.1047e-04 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 6.0957 - val_loss: 2.3195e-04 - val_mean_absolute_error: 0.0062 - val_mean_absolute_percentage_error: 35.8294
# Epoch 50/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 39s 44ms/step - loss: 2.2534e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 5.3974 - val_loss: 2.0063e-04 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 10.9869
# 3009/3009 ━━━━━━━━━━━━━━━━━━━━ 18s 5ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_5060\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_5060\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[22368 25867]
#  [22953 25069]]
