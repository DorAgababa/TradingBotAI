# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.968311 ┆ -0.961899 ┆ -0.959462 ┆ -0.744139 │
# │ -0.968109 ┆ -0.963969 ┆ -0.960285 ┆ -1.140859 │
# │ -0.966712 ┆ -0.964883 ┆ -0.960897 ┆ -1.237162 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.968103    │
# │ -0.966707    │
# │ -0.965175    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return model,y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted,dataset='val'):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
x_test_prepared, y_test_prepared = prepare_lstm_data(x_test, y_test, history_points, day_size)

print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (449448, 10, 4)
# y_train_prepared is (449448, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
model,y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.00005, 
    epochs=50
)
#collect manually results of test
test_loss, test_mae, test_mape = model.evaluate(x_test_prepared, y_test_prepared, verbose=0)
test_mape = 100 - test_mape
y_test_predicted = model.predict(x_test_prepared)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 0.4823 - mean_absolute_error: 0.4532 - mean_absolute_percentage_error: 78.3149 - val_loss: 0.0162 - val_mean_absolute_error: 0.0456 - val_mean_absolute_percentage_error: 30.1298
# Epoch 2/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0142 - mean_absolute_error: 0.0344 - mean_absolute_percentage_error: 26.0211 - val_loss: 0.0116 - val_mean_absolute_error: 0.0203 - val_mean_absolute_percentage_error: 19.7484
# Epoch 3/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0111 - mean_absolute_error: 0.0171 - mean_absolute_percentage_error: 13.2526 - val_loss: 0.0100 - val_mean_absolute_error: 0.0106 - val_mean_absolute_percentage_error: 10.9094
# Epoch 4/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0097 - mean_absolute_error: 0.0093 - mean_absolute_percentage_error: 7.7378 - val_loss: 0.0089 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 6.4672
# Epoch 5/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0086 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 5.6442 - val_loss: 0.0079 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 5.5340
# Epoch 6/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0076 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 4.7155 - val_loss: 0.0069 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 5.0029
# Epoch 7/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0066 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 3.6729 - val_loss: 0.0059 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.6132
# Epoch 8/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0057 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.0573 - val_loss: 0.0049 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.6743
# Epoch 9/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0047 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.5068 - val_loss: 0.0040 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 3.5556
# Epoch 10/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0038 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.3430 - val_loss: 0.0032 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.2795
# Epoch 11/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0030 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.1672 - val_loss: 0.0025 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 2.6215
# Epoch 12/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0023 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 2.0619 - val_loss: 0.0019 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.6922
# Epoch 13/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.6867 - val_loss: 0.0014 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 2.0422
# Epoch 14/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.9680 - val_loss: 0.0011 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.8467
# Epoch 15/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.7209 - val_loss: 8.8704e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.2569
# Epoch 16/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 8.3869e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.6472 - val_loss: 7.1292e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 2.0034
# Epoch 17/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 6.8632e-04 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.7449 - val_loss: 6.0163e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.2769
# Epoch 18/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.7559e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.4991 - val_loss: 5.1234e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.9277
# Epoch 19/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.9122e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.5904 - val_loss: 4.4117e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.9785
# Epoch 20/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.2458e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.4553 - val_loss: 3.8455e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.7863
# Epoch 21/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.7307e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.4064 - val_loss: 3.3857e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.7572
# Epoch 22/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.2885e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.4313 - val_loss: 3.0172e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.3960
# Epoch 23/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.9203e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.4126 - val_loss: 2.6724e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.7681
# Epoch 24/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.6214e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.3633 - val_loss: 2.4150e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.5709
# Epoch 25/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.3412e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3346 - val_loss: 2.1980e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.0917
# Epoch 26/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.0944e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.4828 - val_loss: 1.9571e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.5343
# Epoch 27/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.8619e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.3845 - val_loss: 1.7240e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.1996
# Epoch 28/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.6560e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2992 - val_loss: 1.5308e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.0553
# Epoch 29/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.4903e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.5743 - val_loss: 1.3879e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.1725
# Epoch 30/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.3426e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3482 - val_loss: 1.2668e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.4179
# Epoch 31/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.2148e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3075 - val_loss: 1.1301e-04 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.0810
# Epoch 32/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.1033e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2443 - val_loss: 1.0277e-04 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.3603
# Epoch 33/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0042e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2060 - val_loss: 9.5089e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.4339
# Epoch 34/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.1494e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3545 - val_loss: 8.5693e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.4948
# Epoch 35/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 8.3747e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.4528 - val_loss: 7.7866e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.2971
# Epoch 36/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 7.6209e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.4540 - val_loss: 7.0567e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.3820
# Epoch 37/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 6.9510e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2687 - val_loss: 6.5520e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.3479
# Epoch 38/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 6.4349e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3339 - val_loss: 6.0784e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.3030
# Epoch 39/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 6.0953e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3173 - val_loss: 5.7314e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.5048
# Epoch 40/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.7096e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3594 - val_loss: 5.6365e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3040
# Epoch 41/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.3926e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3105 - val_loss: 5.1596e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.1746
# Epoch 42/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.1213e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.3331 - val_loss: 4.9051e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 1.1282
# Epoch 43/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.8814e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3692 - val_loss: 4.7009e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.1111
# Epoch 44/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.7184e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3425 - val_loss: 4.4489e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 1.0846
# Epoch 45/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.4843e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.5298 - val_loss: 4.4746e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.2474
# Epoch 46/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.3178e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2565 - val_loss: 4.1373e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.1562
# Epoch 47/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.1306e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2311 - val_loss: 3.9348e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 0.9854
# Epoch 48/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.0009e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.1967 - val_loss: 3.8388e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.2659
# Epoch 49/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.8441e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2668 - val_loss: 3.7591e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.3932
# Epoch 50/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.7627e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2792 - val_loss: 3.5611e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.0546
# 3009/3009 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
# 3020/3020 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)
y_test_predicted = y_test_scaler.inverse_transform(y_test_predicted)
y_test_prepared = y_test_scaler.inverse_transform(y_test_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
print("Info of our model on validation run")
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')
# Out:
# Info of our model on validation run

# %%
print("Here we go to the most important point, The test run results:")
test_loss, test_mae, test_mape
print(f"test loss : {test_loss}")
print(f"test mae : {test_mae}")
print(f"test success_ratio : {test_mape}")
# Out:
# Here we go to the most important point, The test run results:
# test loss : 3.723543704836629e-05
# test mae : 0.0015021567232906818
# test success_ratio : 99.05458688735962

# %%
print("----this time on test graph----")
plot_stock_price_result(y_test_prepared,y_test_predicted,'test')
# Out:
# ----this time on test graph----

# %%
#For customer if he decide to listen to the model each time the model saying we go up and each time we go down , how much he will make
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_test_prepared,y_test_predicted)
# Out:
# your profit is [42746.3]
