# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.968311 ┆ -0.961899 ┆ -0.959462 ┆ -0.744139 │
# │ -0.968109 ┆ -0.963969 ┆ -0.960285 ┆ -1.140859 │
# │ -0.966712 ┆ -0.964883 ┆ -0.960897 ┆ -1.237162 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.968103    │
# │ -0.966707    │
# │ -0.965175    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (449448, 10, 4)
# y_train_prepared is (449448, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.00005, 
    epochs=50
)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724424731.701539     113 service.cc:145] XLA service 0x7c1804002770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1724424731.701589     113 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1724424731.701593     113 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  53/878 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9407 - mean_absolute_error: 0.7758 - mean_absolute_percentage_error: 105.3341
# I0000 00:00:1724424733.450017     113 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.4607 - mean_absolute_error: 0.4464 - mean_absolute_percentage_error: 66.6429 - val_loss: 0.0144 - val_mean_absolute_error: 0.0343 - val_mean_absolute_percentage_error: 35.0414
# Epoch 2/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0134 - mean_absolute_error: 0.0276 - mean_absolute_percentage_error: 21.4671 - val_loss: 0.0119 - val_mean_absolute_error: 0.0193 - val_mean_absolute_percentage_error: 23.8447
# Epoch 3/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0115 - mean_absolute_error: 0.0168 - mean_absolute_percentage_error: 12.0265 - val_loss: 0.0106 - val_mean_absolute_error: 0.0116 - val_mean_absolute_percentage_error: 13.7191
# Epoch 4/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0103 - mean_absolute_error: 0.0102 - mean_absolute_percentage_error: 8.2647 - val_loss: 0.0095 - val_mean_absolute_error: 0.0074 - val_mean_absolute_percentage_error: 8.8663
# Epoch 5/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0064 - mean_absolute_percentage_error: 6.3095 - val_loss: 0.0084 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 6.0317
# Epoch 6/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0082 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 5.1064 - val_loss: 0.0074 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 5.3215
# Epoch 7/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0072 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 4.3221 - val_loss: 0.0064 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 5.6648
# Epoch 8/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0061 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.0888 - val_loss: 0.0054 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.3335
# Epoch 9/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.3987 - val_loss: 0.0044 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.3854
# Epoch 10/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0041 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 3.2188 - val_loss: 0.0035 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.4162
# Epoch 11/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0033 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.7162 - val_loss: 0.0027 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 2.0655
# Epoch 12/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.4625 - val_loss: 0.0020 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 3.2354
# Epoch 13/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 2.1507 - val_loss: 0.0015 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 2.4699
# Epoch 14/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 2.0499 - val_loss: 0.0011 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.1386
# Epoch 15/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.8645e-04 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.7578 - val_loss: 7.8725e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 2.5224
# Epoch 16/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.3843e-04 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.8411 - val_loss: 6.0516e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.1985
# Epoch 17/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.6928e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.7059 - val_loss: 4.7052e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 2.1922
# Epoch 18/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.4466e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.4358 - val_loss: 3.7415e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.7394
# Epoch 19/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 3.5669e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.5717 - val_loss: 3.0781e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.8987
# Epoch 20/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.9508e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.6631 - val_loss: 2.5896e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.5698
# Epoch 21/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.4916e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.5945 - val_loss: 2.2156e-04 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.2412
# Epoch 22/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 2.1425e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.4616 - val_loss: 1.9240e-04 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.0257
# Epoch 23/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.8623e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3426 - val_loss: 1.6973e-04 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.4215
# Epoch 24/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.6496e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3396 - val_loss: 1.5159e-04 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.3926
# Epoch 25/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.4816e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2951 - val_loss: 1.3754e-04 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.0467
# Epoch 26/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 1.3432e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3666 - val_loss: 1.2620e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.2821
# Epoch 27/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 1.2287e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3839 - val_loss: 1.1498e-04 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 0.9927
# Epoch 28/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.1301e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3791 - val_loss: 1.0773e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.7106
# Epoch 29/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 1.0456e-04 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3450 - val_loss: 9.8718e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 0.9896
# Epoch 30/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.7234e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2855 - val_loss: 9.5060e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.5331
# Epoch 31/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.1396e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3644 - val_loss: 8.6644e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 0.8972
# Epoch 32/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 8.5697e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.3300 - val_loss: 8.1296e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.0782
# Epoch 33/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 7.9739e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.3329 - val_loss: 7.6374e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 0.8760
# Epoch 34/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 7.5788e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3013 - val_loss: 7.2237e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 0.9750
# Epoch 35/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 7.1414e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.2013 - val_loss: 6.9122e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.3212
# Epoch 36/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 6.8000e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3063 - val_loss: 6.6347e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.0708
# Epoch 37/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6.4873e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.3703 - val_loss: 6.2334e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.1100
# Epoch 38/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 6.1642e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2004 - val_loss: 6.0186e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.5187
# Epoch 39/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.9866e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2513 - val_loss: 5.7016e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.0718
# Epoch 40/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.6665e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.2971 - val_loss: 5.6195e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 1.0953
# Epoch 41/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.4188e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.3167 - val_loss: 5.2434e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 1.1394
# Epoch 42/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.2517e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2143 - val_loss: 5.0639e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.1076
# Epoch 43/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 5.0541e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2801 - val_loss: 4.8417e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 1.5561
# Epoch 44/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.8753e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.2266 - val_loss: 4.8091e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 0.9894
# Epoch 45/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.6814e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.1429 - val_loss: 4.6063e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 0.9162
# Epoch 46/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.5656e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2548 - val_loss: 4.4947e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 1.1130
# Epoch 47/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 4.3768e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.3182 - val_loss: 4.2497e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 0.8903
# Epoch 48/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.2856e-05 - mean_absolute_error: 0.0014 - mean_absolute_percentage_error: 1.1834 - val_loss: 4.1867e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 1.2614
# Epoch 49/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.1770e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.2497 - val_loss: 4.7506e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 2.2910
# Epoch 50/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 4.0829e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.4286 - val_loss: 3.8858e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 1.2236
# 3009/3009 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# /tmp/ipykernel_36/2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# /tmp/ipykernel_36/2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[24062 24166]
#  [23248 24781]]

# %%
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_val_prepared,y_val_predicted)
# Out:
# your profit is [40338.3]
