# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.968311 ┆ -0.961899 ┆ -0.959462 ┆ -0.744139 │
# │ -0.968109 ┆ -0.963969 ┆ -0.960285 ┆ -1.140859 │
# │ -0.966712 ┆ -0.964883 ┆ -0.960897 ┆ -1.237162 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.968103    │
# │ -0.966707    │
# │ -0.965175    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="tanh"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="tanh"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="tanh"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="tanh", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="tanh", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="tanh", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="tanh"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="tanh"))
        else:
            model.add(Dense(regular_layer1_size, activation="tanh"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="tanh"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="tanh"))
        else:
            model.add(Dense(regular_layer2_size, activation="tanh"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (449448, 10, 4)
# y_train_prepared is (449448, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.00005, 
    epochs=50
)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.1285 - mean_absolute_error: 0.1957 - mean_absolute_percentage_error: 33.3047 - val_loss: 0.0169 - val_mean_absolute_error: 0.0473 - val_mean_absolute_percentage_error: 13.8329
# Epoch 2/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0149 - mean_absolute_error: 0.0325 - mean_absolute_percentage_error: 8.8802 - val_loss: 0.0129 - val_mean_absolute_error: 0.0109 - val_mean_absolute_percentage_error: 9.8333
# Epoch 3/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0089 - mean_absolute_percentage_error: 7.3712 - val_loss: 0.0121 - val_mean_absolute_error: 0.0077 - val_mean_absolute_percentage_error: 8.3993
# Epoch 4/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 0.0119 - mean_absolute_error: 0.0064 - mean_absolute_percentage_error: 5.2949 - val_loss: 0.0113 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 6.5636
# Epoch 5/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0110 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 3.9578 - val_loss: 0.0103 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 3.7209
# Epoch 6/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0100 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 2.6070 - val_loss: 0.0092 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 2.9396
# Epoch 7/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0088 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 2.0251 - val_loss: 0.0079 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 2.3058
# Epoch 8/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0075 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 1.5630 - val_loss: 0.0065 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 1.8894
# Epoch 9/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.3109 - val_loss: 0.0051 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.4347
# Epoch 10/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0048 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 1.2312 - val_loss: 0.0038 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.0331
# Epoch 11/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0035 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.2514 - val_loss: 0.0026 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.0068
# Epoch 12/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.2855 - val_loss: 0.0017 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.0135
# Epoch 13/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.3265 - val_loss: 0.0011 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.0016
# Epoch 14/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 9.8349e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5043 - val_loss: 6.9640e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.1113
# Epoch 15/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 6.2587e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.4342 - val_loss: 4.5807e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.1816
# Epoch 16/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.1762e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.7193 - val_loss: 3.2164e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.1902
# Epoch 17/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 2.9767e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5429 - val_loss: 2.4231e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.1130
# Epoch 18/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 2.2758e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5379 - val_loss: 1.9512e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.5775
# Epoch 19/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.8509e-04 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 1.5860 - val_loss: 1.6511e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.2162
# Epoch 20/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.5734e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5556 - val_loss: 1.4387e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.2209
# Epoch 21/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.3785e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5231 - val_loss: 1.2843e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.5905
# Epoch 22/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 1.2409e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5341 - val_loss: 1.1844e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.2348
# Epoch 23/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.1300e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.4571 - val_loss: 1.0732e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.5014
# Epoch 24/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 1.0408e-04 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.6013 - val_loss: 1.0197e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.1236
# Epoch 25/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 9.6992e-05 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.4680 - val_loss: 9.4265e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.2623
# Epoch 26/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 9.1111e-05 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5108 - val_loss: 8.8556e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.2747
# Epoch 27/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.6385e-05 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.5839 - val_loss: 8.3921e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.1077
# Epoch 28/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 8.1747e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.4938 - val_loss: 8.0258e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.3562
# Epoch 29/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.7884e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.3457 - val_loss: 7.6856e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.2901
# Epoch 30/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.4560e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.3862 - val_loss: 7.4787e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.1712
# Epoch 31/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 7.2132e-05 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 1.4805 - val_loss: 7.3233e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.0650
# Epoch 32/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 6.9322e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.4712 - val_loss: 6.8595e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.4323
# Epoch 33/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 6.7209e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.3351 - val_loss: 6.6461e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.0566
# Epoch 34/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 6.4664e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.2979 - val_loss: 6.4068e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3114
# Epoch 35/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 6.2467e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.2824 - val_loss: 6.1914e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.1624
# Epoch 36/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 6.0514e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.3686 - val_loss: 6.0486e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.1973
# Epoch 37/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.8871e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.4019 - val_loss: 5.8786e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3576
# Epoch 38/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.7323e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.3176 - val_loss: 5.7918e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.3721
# Epoch 39/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.6703e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.2969 - val_loss: 5.6662e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3255
# Epoch 40/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.4440e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.2148 - val_loss: 5.5291e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.5788
# Epoch 41/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.3251e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.3746 - val_loss: 5.3421e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.1222
# Epoch 42/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.2514e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.4008 - val_loss: 5.5030e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.4443
# Epoch 43/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.1448e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.3314 - val_loss: 5.2220e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.2544
# Epoch 44/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 5.0140e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.2244 - val_loss: 5.1008e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.6272
# Epoch 45/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.9136e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.2944 - val_loss: 5.0443e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.7963
# Epoch 46/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.8410e-05 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 1.4486 - val_loss: 4.9077e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.5800
# Epoch 47/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.7161e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.4144 - val_loss: 4.7710e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3602
# Epoch 48/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.5997e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.3339 - val_loss: 4.6617e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.4596
# Epoch 49/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.5506e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.1900 - val_loss: 4.6485e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.4289
# Epoch 50/50
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 4.5185e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.3156 - val_loss: 4.5397e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.5345
# 3009/3009 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# /tmp/ipykernel_36/2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# /tmp/ipykernel_36/2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[23645 24583]
#  [23499 24530]]

# %%
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_val_prepared,y_val_predicted)
# Out:
# your profit is [40791.1]
