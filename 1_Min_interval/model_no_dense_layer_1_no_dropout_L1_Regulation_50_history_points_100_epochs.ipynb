# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.968311 ┆ -0.961899 ┆ -0.959462 ┆ -0.744139 │
# │ -0.968109 ┆ -0.963969 ┆ -0.960285 ┆ -1.140859 │
# │ -0.966712 ┆ -0.964883 ┆ -0.960897 ┆ -1.237162 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.968103    │
# │ -0.966707    │
# │ -0.965175    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1),return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 50
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (400328, 50, 4)
# y_train_prepared is (400328, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=0, 
    regular_layer1_size=0, 
    regular_layer2_size=0,
    L1=0.0002, 
    L2=0, 
    dropout=0, 
    history_points=50, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.00005, 
    epochs=100
)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.3383 - mean_absolute_error: 0.4084 - mean_absolute_percentage_error: 81.1345 - val_loss: 0.0213 - val_mean_absolute_error: 0.0622 - val_mean_absolute_percentage_error: 47.9408
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0277 - mean_absolute_error: 0.0484 - mean_absolute_percentage_error: 39.0486 - val_loss: 0.0164 - val_mean_absolute_error: 0.0334 - val_mean_absolute_percentage_error: 31.0559
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0231 - mean_absolute_error: 0.0296 - mean_absolute_percentage_error: 24.2270 - val_loss: 0.0153 - val_mean_absolute_error: 0.0251 - val_mean_absolute_percentage_error: 28.8964
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0218 - mean_absolute_error: 0.0241 - mean_absolute_percentage_error: 17.2494 - val_loss: 0.0147 - val_mean_absolute_error: 0.0204 - val_mean_absolute_percentage_error: 26.6203
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0179 - mean_absolute_error: 0.0197 - mean_absolute_percentage_error: 14.3375 - val_loss: 0.0141 - val_mean_absolute_error: 0.0162 - val_mean_absolute_percentage_error: 29.1527
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0149 - mean_absolute_error: 0.0154 - mean_absolute_percentage_error: 14.0946 - val_loss: 0.0135 - val_mean_absolute_error: 0.0122 - val_mean_absolute_percentage_error: 25.8558
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0139 - mean_absolute_error: 0.0120 - mean_absolute_percentage_error: 13.5966 - val_loss: 0.0128 - val_mean_absolute_error: 0.0094 - val_mean_absolute_percentage_error: 18.3533
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0129 - mean_absolute_error: 0.0093 - mean_absolute_percentage_error: 9.6725 - val_loss: 0.0121 - val_mean_absolute_error: 0.0077 - val_mean_absolute_percentage_error: 15.3573
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0121 - mean_absolute_error: 0.0078 - mean_absolute_percentage_error: 8.0480 - val_loss: 0.0113 - val_mean_absolute_error: 0.0067 - val_mean_absolute_percentage_error: 12.6725
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0113 - mean_absolute_error: 0.0066 - mean_absolute_percentage_error: 6.5366 - val_loss: 0.0104 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 7.6359
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0103 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 5.2422 - val_loss: 0.0094 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 4.7334
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0092 - mean_absolute_error: 0.0049 - mean_absolute_percentage_error: 3.6299 - val_loss: 0.0084 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 5.3096
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0081 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 3.3778 - val_loss: 0.0073 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 5.8217
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0070 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 3.5453 - val_loss: 0.0062 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 4.5999
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0060 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 2.8170 - val_loss: 0.0053 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 4.5062
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0051 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 2.7732 - val_loss: 0.0043 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 2.5502
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0041 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 2.9763 - val_loss: 0.0036 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.0275
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0035 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 2.5135 - val_loss: 0.0030 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.9813
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0028 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 2.4355 - val_loss: 0.0024 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.5743
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0024 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 3.2875 - val_loss: 0.0021 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.8389
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 0.0020 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 3.3493 - val_loss: 0.0018 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.3628
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.3457 - val_loss: 0.0015 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.1208
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.1641 - val_loss: 0.0013 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.2435
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.3649 - val_loss: 0.0012 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 5.3349
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 2.7028 - val_loss: 0.0010 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 5.8519
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 9.7799e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.7118 - val_loss: 8.6424e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 2.2251
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 8.3232e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.8608 - val_loss: 7.3187e-04 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.2192
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.1097e-04 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 3.0404 - val_loss: 6.2823e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.7668
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.0566e-04 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 2.2934 - val_loss: 5.2963e-04 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 2.9752
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.1135e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.9570 - val_loss: 4.5092e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.9210
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.3460e-04 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.0546 - val_loss: 3.8122e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.7069
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 3.7075e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 2.0009 - val_loss: 3.3254e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.3172
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 3.2404e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7546 - val_loss: 2.8927e-04 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 1.4900
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.8085e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.5532 - val_loss: 2.5684e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 1.5348
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.5052e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.6174 - val_loss: 2.3213e-04 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.7075
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.2516e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.6123 - val_loss: 2.0746e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.5983
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 2.0256e-04 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.5752 - val_loss: 1.8480e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.3522
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 1.8074e-04 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.7441 - val_loss: 1.6199e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.6054
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 1.5749e-04 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.7002 - val_loss: 1.3632e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.4332
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 1.3288e-04 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.5628 - val_loss: 1.2005e-04 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 4.2305
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 1.1742e-04 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.7134 - val_loss: 1.0845e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 3.0089
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 1.0584e-04 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.7258 - val_loss: 9.5939e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.5734
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 9.7732e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.6165 - val_loss: 8.9142e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 2.6487
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 9.0243e-05 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 1.6040 - val_loss: 8.6822e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 2.4193
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 8.4078e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.5172 - val_loss: 7.8213e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.2713
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 8.1170e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.4954 - val_loss: 7.8763e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.6231
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.7949e-05 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 1.5078 - val_loss: 7.8191e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 2.0333
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.8135e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.5998 - val_loss: 7.3769e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.4511
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.6273e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.5894 - val_loss: 7.4749e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.9170
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.5019e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.4981 - val_loss: 7.9911e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 2.0695
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.3520e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.4648 - val_loss: 7.0771e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.3370
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.3020e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.6593 - val_loss: 7.0087e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.2904
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.2256e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.4981 - val_loss: 6.8692e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.6658
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 7.1492e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7082 - val_loss: 6.9450e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.6676
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.9765e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.6533 - val_loss: 6.6532e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.1668
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.8645e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.6722 - val_loss: 7.0402e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 2.2340
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.8166e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7094 - val_loss: 6.5381e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3038
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.7083e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.5659 - val_loss: 6.3628e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.2898
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.7256e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.6725 - val_loss: 7.6250e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 2.0742
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.6125e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.8289 - val_loss: 6.2665e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.4214
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.5361e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.6799 - val_loss: 6.3057e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.3784
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.3991e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.6352 - val_loss: 6.0585e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.2060
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.3706e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7124 - val_loss: 6.1480e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.4354
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.4044e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.6942 - val_loss: 5.8882e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.0285
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.3019e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7285 - val_loss: 5.8293e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.3598
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.1669e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.6654 - val_loss: 6.2188e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.9719
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.2192e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.7379 - val_loss: 6.2034e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 1.4918
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.2142e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.6372 - val_loss: 5.6822e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.2065
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.0263e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.6322 - val_loss: 6.0474e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 1.7976
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.2188e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.7422 - val_loss: 5.9566e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.9765
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.9365e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.8230 - val_loss: 5.7474e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 2.3542
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.8705e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7357 - val_loss: 5.9778e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 2.0385
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.7781e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.8647 - val_loss: 5.7931e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 2.2816
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.7765e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.5634 - val_loss: 5.8509e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 1.7865
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 6.1091e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 1.6241 - val_loss: 5.3147e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.2985
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.7220e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.5830 - val_loss: 5.6068e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 2.0453
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.7551e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.7478 - val_loss: 5.1806e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.1323
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.6385e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.6254 - val_loss: 5.2181e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.7759
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.6287e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.8760 - val_loss: 5.3455e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.6147
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.4720e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 2.0222 - val_loss: 6.4260e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.9856
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.7097e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.7203 - val_loss: 5.8035e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 2.5843
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.2891e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.5900 - val_loss: 5.1012e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.2691
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.2609e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.6874 - val_loss: 5.0285e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.2623
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.4117e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.6556 - val_loss: 5.9676e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 2.6656
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.3409e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.6200 - val_loss: 4.8929e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.2686
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.1475e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7413 - val_loss: 5.5691e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 3.3304
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.1941e-05 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 1.7179 - val_loss: 5.4742e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 1.9676
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.1529e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.7222 - val_loss: 4.7330e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 1.6230
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 5.2879e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.6965 - val_loss: 5.0258e-05 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 1.5094
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.2491e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.8927 - val_loss: 4.8742e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 1.4201
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.2121e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.7385 - val_loss: 4.8244e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 1.8195
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.3244e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.8049 - val_loss: 4.6227e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.7404
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.0403e-05 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 1.7171 - val_loss: 4.6327e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 1.3626
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.1328e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.8441 - val_loss: 4.7794e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.6573
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.0700e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 1.8272 - val_loss: 4.5244e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.3980
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.1390e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 1.8097 - val_loss: 4.7032e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.6878
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.8901e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.1348 - val_loss: 4.5358e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.6468
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.7942e-05 - mean_absolute_error: 0.0022 - mean_absolute_percentage_error: 1.7751 - val_loss: 4.4155e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 1.4056
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 5.1837e-05 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.0469 - val_loss: 5.5460e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 2.1609
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 4.9358e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 1.8072 - val_loss: 4.7027e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 1.3024
# 2680/2680 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# /tmp/ipykernel_36/2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# /tmp/ipykernel_36/2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[20856 22077]
#  [21188 21616]]

# %%
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_val_prepared,y_val_predicted)
# Out:
# your profit is [51411.]
