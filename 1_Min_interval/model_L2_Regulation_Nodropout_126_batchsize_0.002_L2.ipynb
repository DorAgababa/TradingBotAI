# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬──────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪══════════╡
# │ -0.826309 ┆ -0.841511 ┆ -0.847228 ┆ 1.866119 │
# │ -0.827013 ┆ -0.836676 ┆ -0.845299 ┆ 2.815468 │
# │ -0.823052 ┆ -0.832132 ┆ -0.843176 ┆ 3.606465 │
# └───────────┴───────────┴───────────┴──────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.827027    │
# │ -0.823065    │
# │ -0.822361    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (449448, 10, 4)
# y_train_prepared is (449448, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=126, 
    learning_rate=0.00005, 
    epochs=50
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 63s 16ms/step - loss: 0.2657 - mean_absolute_error: 0.1989 - mean_absolute_percentage_error: 49.6480 - val_loss: 0.0475 - val_mean_absolute_error: 0.0089 - val_mean_absolute_percentage_error: 52.1958
# Epoch 2/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 55s 15ms/step - loss: 0.0349 - mean_absolute_error: 0.0063 - mean_absolute_percentage_error: 7.3948 - val_loss: 0.0094 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 15.7310
# Epoch 3/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 0.0061 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.5334 - val_loss: 0.0012 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 19.2417
# Epoch 4/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 57s 16ms/step - loss: 8.3729e-04 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 4.4813 - val_loss: 3.9702e-04 - val_mean_absolute_error: 0.0057 - val_mean_absolute_percentage_error: 9.8406
# Epoch 5/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 3.0371e-04 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 2.3988 - val_loss: 2.2008e-04 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 10.1268
# Epoch 6/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 55s 16ms/step - loss: 1.7592e-04 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 6.0220 - val_loss: 1.2447e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 9.9802
# Epoch 7/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 57s 16ms/step - loss: 1.2112e-04 - mean_absolute_error: 0.0024 - mean_absolute_percentage_error: 2.7078 - val_loss: 9.5565e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 11.6911
# Epoch 8/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 9.1169e-05 - mean_absolute_error: 0.0025 - mean_absolute_percentage_error: 4.4050 - val_loss: 8.0436e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 12.4244
# Epoch 9/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 8.3779e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.1785 - val_loss: 8.1293e-05 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 10.0102
# Epoch 10/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 6.7247e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 6.9742 - val_loss: 5.6470e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 8.0479
# Epoch 11/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 6.1967e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 2.9997 - val_loss: 4.8992e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 8.7816
# Epoch 12/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 5.5702e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 4.5445 - val_loss: 5.8128e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 7.4022
# Epoch 13/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 57s 16ms/step - loss: 5.3525e-05 - mean_absolute_error: 0.0027 - mean_absolute_percentage_error: 3.1631 - val_loss: 8.4407e-05 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 33.2066
# Epoch 14/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 54s 15ms/step - loss: 5.2256e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.3781 - val_loss: 9.9427e-05 - val_mean_absolute_error: 0.0073 - val_mean_absolute_percentage_error: 19.5701
# Epoch 15/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 4.9961e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.8600 - val_loss: 5.1953e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 7.6758
# Epoch 16/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 4.9380e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.6847 - val_loss: 3.6267e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 9.2683
# Epoch 17/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 4.8539e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.6365 - val_loss: 1.0902e-04 - val_mean_absolute_error: 0.0075 - val_mean_absolute_percentage_error: 20.4942
# Epoch 18/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 4.6736e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.4271 - val_loss: 4.8696e-05 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 22.3142
# Epoch 19/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 4.3839e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.7202 - val_loss: 3.6861e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 7.1307
# Epoch 20/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 4.6567e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.1428 - val_loss: 1.2147e-04 - val_mean_absolute_error: 0.0086 - val_mean_absolute_percentage_error: 37.7845
# Epoch 21/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 4.3092e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.4780 - val_loss: 3.6844e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 12.2924
# Epoch 22/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 4.4725e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.8041 - val_loss: 4.8001e-05 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 8.7994
# Epoch 23/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 41s 12ms/step - loss: 4.1939e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.5120 - val_loss: 7.1783e-05 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 8.9716
# Epoch 24/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 44s 12ms/step - loss: 4.2141e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.4054 - val_loss: 3.1824e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 12.7925
# Epoch 25/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 46s 13ms/step - loss: 4.1122e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.1473 - val_loss: 3.6571e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 7.4057
# Epoch 26/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 47s 13ms/step - loss: 4.1906e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.0871 - val_loss: 3.6143e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 11.5530
# Epoch 27/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 47s 13ms/step - loss: 4.1085e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.7580 - val_loss: 3.6513e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 19.4948
# Epoch 28/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 60s 17ms/step - loss: 3.8617e-05 - mean_absolute_error: 0.0028 - mean_absolute_percentage_error: 3.6979 - val_loss: 8.0463e-05 - val_mean_absolute_error: 0.0065 - val_mean_absolute_percentage_error: 8.4301
# Epoch 29/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 60s 17ms/step - loss: 4.0406e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.2985 - val_loss: 3.8818e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 7.9256
# Epoch 30/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 62s 17ms/step - loss: 4.0453e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.7506 - val_loss: 1.0891e-04 - val_mean_absolute_error: 0.0067 - val_mean_absolute_percentage_error: 27.6051
# Epoch 31/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 61s 17ms/step - loss: 4.1204e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.6951 - val_loss: 4.1032e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 23.5010
# Epoch 32/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 60s 17ms/step - loss: 4.2157e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.6895 - val_loss: 3.7366e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 8.2554
# Epoch 33/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 49s 14ms/step - loss: 4.2970e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.9422 - val_loss: 3.0601e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 10.6460
# Epoch 34/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 15ms/step - loss: 4.1562e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.2845 - val_loss: 2.8714e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 13.7275
# Epoch 35/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 56s 16ms/step - loss: 3.8874e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.3657 - val_loss: 3.0372e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 7.2450
# Epoch 36/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 58s 16ms/step - loss: 3.9769e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.2522 - val_loss: 1.3161e-04 - val_mean_absolute_error: 0.0101 - val_mean_absolute_percentage_error: 32.3894
# Epoch 37/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 47s 13ms/step - loss: 3.9735e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.8181 - val_loss: 6.1549e-05 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 13.0051
# Epoch 38/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 47s 13ms/step - loss: 3.8188e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.0883 - val_loss: 9.2449e-05 - val_mean_absolute_error: 0.0069 - val_mean_absolute_percentage_error: 14.7559
# Epoch 39/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 47s 13ms/step - loss: 3.9374e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 6.6705 - val_loss: 3.9311e-05 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 18.9149
# Epoch 40/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 55s 15ms/step - loss: 3.7439e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.3743 - val_loss: 3.6191e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 15.4125
# Epoch 41/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 60s 17ms/step - loss: 3.7603e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.9082 - val_loss: 3.0771e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 7.9220
# Epoch 42/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 61s 17ms/step - loss: 3.7198e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.0285 - val_loss: 5.3234e-05 - val_mean_absolute_error: 0.0053 - val_mean_absolute_percentage_error: 29.5521
# Epoch 43/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 60s 17ms/step - loss: 3.7177e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.0142 - val_loss: 3.5367e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 20.2417
# Epoch 44/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 60s 17ms/step - loss: 3.6850e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.3346 - val_loss: 2.8576e-05 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 10.6849
# Epoch 45/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 61s 17ms/step - loss: 3.3368e-05 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 4.7624 - val_loss: 1.6423e-04 - val_mean_absolute_error: 0.0087 - val_mean_absolute_percentage_error: 32.7565
# Epoch 46/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 88s 25ms/step - loss: 3.7816e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 3.4519 - val_loss: 4.7137e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 8.9247
# Epoch 47/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 180s 48ms/step - loss: 3.6431e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.5809 - val_loss: 1.1845e-04 - val_mean_absolute_error: 0.0071 - val_mean_absolute_percentage_error: 13.5942
# Epoch 48/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 114s 30ms/step - loss: 3.7991e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.0923 - val_loss: 5.9777e-05 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 9.9627
# Epoch 49/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 132s 27ms/step - loss: 3.7786e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.7327 - val_loss: 1.7316e-04 - val_mean_absolute_error: 0.0113 - val_mean_absolute_percentage_error: 17.4770
# Epoch 50/50
# 3568/3568 ━━━━━━━━━━━━━━━━━━━━ 83s 22ms/step - loss: 3.9144e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.1043 - val_loss: 5.1045e-05 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 11.1279
# 3009/3009 ━━━━━━━━━━━━━━━━━━━━ 25s 7ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_13112\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_13112\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[23332 24903]
#  [23685 24337]]

# %%
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_val_prepared,y_val_predicted)
# Out:
# your profit is [43352.85]
