# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['NEXT_1_MIN']
    x = data.drop('NEXT_1_MIN')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬──────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520  │
# │ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪══════════╡
# │ -0.826309 ┆ -0.841511 ┆ -0.847228 ┆ 1.866119 │
# │ -0.827013 ┆ -0.836676 ┆ -0.845299 ┆ 2.815468 │
# │ -0.823052 ┆ -0.832132 ┆ -0.843176 ┆ 3.606465 │
# └───────────┴───────────┴───────────┴──────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.827027    │
# │ -0.823065    │
# │ -0.822361    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=375
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (460500, 4)
# y_train is (460500, 1)
# x_train_prepared is (449448, 10, 4)
# y_train_prepared is (449448, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.00005, 
    epochs=100
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 157s 92ms/step - loss: 0.3123 - mean_absolute_error: 0.3696 - mean_absolute_percentage_error: 83.7655 - val_loss: 0.0141 - val_mean_absolute_error: 0.0328 - val_mean_absolute_percentage_error: 52.6442
# Epoch 2/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 87s 94ms/step - loss: 0.0132 - mean_absolute_error: 0.0286 - mean_absolute_percentage_error: 20.4295 - val_loss: 0.0113 - val_mean_absolute_error: 0.0187 - val_mean_absolute_percentage_error: 83.4794
# Epoch 3/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 116s 118ms/step - loss: 0.0110 - mean_absolute_error: 0.0173 - mean_absolute_percentage_error: 20.5810 - val_loss: 0.0098 - val_mean_absolute_error: 0.0116 - val_mean_absolute_percentage_error: 45.4174
# Epoch 4/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 93s 94ms/step - loss: 0.0095 - mean_absolute_error: 0.0107 - mean_absolute_percentage_error: 12.7753 - val_loss: 0.0086 - val_mean_absolute_error: 0.0068 - val_mean_absolute_percentage_error: 26.5586
# Epoch 5/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 103s 105ms/step - loss: 0.0083 - mean_absolute_error: 0.0063 - mean_absolute_percentage_error: 8.8021 - val_loss: 0.0075 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 18.5469
# Epoch 6/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 116s 123ms/step - loss: 0.0073 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 6.5372 - val_loss: 0.0065 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 14.3216
# Epoch 7/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 116s 117ms/step - loss: 0.0063 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 5.2242 - val_loss: 0.0055 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 12.7451
# Epoch 8/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 134s 110ms/step - loss: 0.0053 - mean_absolute_error: 0.0026 - mean_absolute_percentage_error: 4.7133 - val_loss: 0.0046 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 8.1921
# Epoch 9/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 105s 114ms/step - loss: 0.0044 - mean_absolute_error: 0.0023 - mean_absolute_percentage_error: 4.3920 - val_loss: 0.0037 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 7.2700
# Epoch 10/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 87s 97ms/step - loss: 0.0035 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 2.5929 - val_loss: 0.0029 - val_mean_absolute_error: 0.0022 - val_mean_absolute_percentage_error: 7.1178
# Epoch 11/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 91s 99ms/step - loss: 0.0027 - mean_absolute_error: 0.0021 - mean_absolute_percentage_error: 6.5137 - val_loss: 0.0022 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 9.9294
# Epoch 12/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 92s 99ms/step - loss: 0.0021 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 2.8709 - val_loss: 0.0017 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 10.3547
# Epoch 13/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 87s 94ms/step - loss: 0.0015 - mean_absolute_error: 0.0019 - mean_absolute_percentage_error: 2.8032 - val_loss: 0.0012 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 9.7548
# Epoch 14/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 86s 92ms/step - loss: 0.0011 - mean_absolute_error: 0.0020 - mean_absolute_percentage_error: 3.7321 - val_loss: 9.0526e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 10.0246
# Epoch 15/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 89s 97ms/step - loss: 8.4930e-04 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 3.8306 - val_loss: 6.9678e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 11.0426
# Epoch 16/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 89s 99ms/step - loss: 6.5760e-04 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 3.0538 - val_loss: 5.4978e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 12.1615
# Epoch 17/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 81s 90ms/step - loss: 5.2232e-04 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 3.0122 - val_loss: 4.4745e-04 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 12.1433
# Epoch 18/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 79s 88ms/step - loss: 4.2705e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.1716 - val_loss: 3.7747e-04 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 10.4685
# Epoch 19/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 78s 87ms/step - loss: 3.5884e-04 - mean_absolute_error: 0.0018 - mean_absolute_percentage_error: 2.9256 - val_loss: 3.1724e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 12.6647
# Epoch 20/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 79s 87ms/step - loss: 3.0567e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.2647 - val_loss: 2.7223e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 12.3647
# Epoch 21/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 81s 90ms/step - loss: 2.6283e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.8030 - val_loss: 2.3624e-04 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 11.4886
# Epoch 22/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 83s 90ms/step - loss: 2.2922e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.5060 - val_loss: 2.1135e-04 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 11.2905
# Epoch 23/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 78s 86ms/step - loss: 2.0280e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 3.0694 - val_loss: 1.8346e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 11.3341
# Epoch 24/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 79s 87ms/step - loss: 1.7969e-04 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 1.9766 - val_loss: 1.6372e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 9.3139
# Epoch 25/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 84s 91ms/step - loss: 1.6097e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.9250 - val_loss: 1.4778e-04 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 9.3665
# Epoch 26/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 80s 89ms/step - loss: 1.4539e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.1473 - val_loss: 1.3857e-04 - val_mean_absolute_error: 0.0021 - val_mean_absolute_percentage_error: 11.3654
# Epoch 27/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 79s 85ms/step - loss: 1.3293e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 6.6624 - val_loss: 1.2330e-04 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 8.3106
# Epoch 28/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 73s 80ms/step - loss: 1.2160e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 6.4549 - val_loss: 1.1308e-04 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 7.7171
# Epoch 29/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 70s 78ms/step - loss: 1.1176e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 5.2855 - val_loss: 1.0370e-04 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 8.2958
# Epoch 30/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 69s 77ms/step - loss: 1.0259e-04 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.4784 - val_loss: 9.5747e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 8.0906
# Epoch 31/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - loss: 9.4531e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.5157 - val_loss: 8.9805e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 9.5088
# Epoch 32/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 68s 74ms/step - loss: 8.8137e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.1397 - val_loss: 8.2345e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 7.9916
# Epoch 33/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 81s 74ms/step - loss: 8.1380e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.3560 - val_loss: 7.6025e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 9.7721
# Epoch 34/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - loss: 7.5486e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 3.8906 - val_loss: 7.2664e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 7.6826
# Epoch 35/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 70s 78ms/step - loss: 7.1458e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.7382 - val_loss: 6.6736e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 10.6403
# Epoch 36/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 70s 79ms/step - loss: 6.6918e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 4.2958 - val_loss: 6.3152e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 8.8586
# Epoch 37/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 72s 78ms/step - loss: 6.3608e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.9117 - val_loss: 5.9563e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 9.3312
# Epoch 38/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 68s 76ms/step - loss: 6.0100e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.4904 - val_loss: 5.6443e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.3022
# Epoch 39/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 67s 76ms/step - loss: 5.6944e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 5.6211 - val_loss: 5.4542e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 11.5863
# Epoch 40/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - loss: 5.4087e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.2462 - val_loss: 5.1647e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 11.4588
# Epoch 41/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 69s 77ms/step - loss: 5.1439e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.0435 - val_loss: 4.9094e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 8.5166
# Epoch 42/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 66s 74ms/step - loss: 4.9251e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.1872 - val_loss: 4.7260e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 9.6084
# Epoch 43/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - loss: 4.7187e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.5416 - val_loss: 4.6430e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 11.5301
# Epoch 44/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 68s 76ms/step - loss: 4.5185e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 4.0739 - val_loss: 4.3558e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 8.2877
# Epoch 45/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 67s 75ms/step - loss: 4.3269e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.8739 - val_loss: 4.1393e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 9.1685
# Epoch 46/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - loss: 4.2256e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.0651 - val_loss: 4.0340e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 12.2330
# Epoch 47/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - loss: 4.0854e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.3895 - val_loss: 3.8620e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 8.3354
# Epoch 48/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 66s 75ms/step - loss: 3.9008e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.6177 - val_loss: 3.8089e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 9.5239
# Epoch 49/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 62s 69ms/step - loss: 3.8714e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.1157 - val_loss: 3.5817e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.7176
# Epoch 50/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 63s 70ms/step - loss: 3.6642e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.2265 - val_loss: 3.5416e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.7204
# Epoch 51/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 64s 72ms/step - loss: 3.6043e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.2225 - val_loss: 3.3905e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 9.2393
# Epoch 52/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 63s 71ms/step - loss: 3.5047e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.5506 - val_loss: 3.4576e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 9.7460
# Epoch 53/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 63s 71ms/step - loss: 3.3660e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 3.6986 - val_loss: 3.2010e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.5540
# Epoch 54/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 60s 68ms/step - loss: 3.3205e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.7676 - val_loss: 3.2577e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 6.9363
# Epoch 55/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 60s 68ms/step - loss: 3.2532e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 3.3727 - val_loss: 3.0283e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 7.3450
# Epoch 56/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 60s 67ms/step - loss: 3.2300e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.0870 - val_loss: 3.1198e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 10.7968
# Epoch 57/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 3.1177e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 3.5706 - val_loss: 2.9604e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 10.4203
# Epoch 58/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 3.1144e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.8860 - val_loss: 2.8342e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.5535
# Epoch 59/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 2.9389e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.0982 - val_loss: 2.8636e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 9.8543
# Epoch 60/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 2.8459e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 1.9189 - val_loss: 2.7504e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 7.2574
# Epoch 61/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 2.8312e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.9800 - val_loss: 2.7793e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 5.7545
# Epoch 62/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 60s 67ms/step - loss: 2.7809e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.2270 - val_loss: 2.5979e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 6.6753
# Epoch 63/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 2.7132e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.4303 - val_loss: 2.5436e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 8.4214
# Epoch 64/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 58s 65ms/step - loss: 2.7387e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.8557 - val_loss: 2.5457e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 6.4605
# Epoch 65/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 61s 68ms/step - loss: 2.6037e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.6795 - val_loss: 2.5852e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 8.1346
# Epoch 66/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 58s 66ms/step - loss: 2.5836e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 4.4966 - val_loss: 2.5509e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 7.5781
# Epoch 67/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 60s 67ms/step - loss: 2.5679e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.6438 - val_loss: 2.3520e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 9.1074
# Epoch 68/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 2.5670e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.6098 - val_loss: 2.3658e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.6651
# Epoch 69/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 59s 66ms/step - loss: 2.4506e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.6602 - val_loss: 2.4068e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 6.8067
# Epoch 70/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 54s 60ms/step - loss: 2.4768e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.8442 - val_loss: 2.3342e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 9.6579
# Epoch 71/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 51s 58ms/step - loss: 2.3345e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 2.4774 - val_loss: 2.2974e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 6.1999
# Epoch 72/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 57ms/step - loss: 2.3296e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.7762 - val_loss: 2.2318e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.2604
# Epoch 73/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 2.4069e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.2893 - val_loss: 2.1704e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.1708
# Epoch 74/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 49s 55ms/step - loss: 2.3350e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.9155 - val_loss: 2.3021e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 5.9025
# Epoch 75/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 49s 56ms/step - loss: 2.3072e-05 - mean_absolute_error: 0.0015 - mean_absolute_percentage_error: 3.9403 - val_loss: 2.1285e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 7.1626
# Epoch 76/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 2.2121e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.6314 - val_loss: 2.2194e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 10.2732
# Epoch 77/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 2.2509e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.7863 - val_loss: 2.0181e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 6.7861
# Epoch 78/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 2.2283e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.8287 - val_loss: 2.0875e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 7.9559
# Epoch 79/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 49s 56ms/step - loss: 2.2707e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.4567 - val_loss: 2.1114e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 7.3240
# Epoch 80/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 57ms/step - loss: 2.1329e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.8813 - val_loss: 1.9746e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 8.7836
# Epoch 81/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 49s 55ms/step - loss: 2.1435e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.0589 - val_loss: 1.9851e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 10.1890
# Epoch 82/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 2.1389e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 5.1912 - val_loss: 2.0158e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 9.6691
# Epoch 83/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - loss: 2.1458e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.6032 - val_loss: 2.1169e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 6.0509
# Epoch 84/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 45s 51ms/step - loss: 2.0800e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 4.4688 - val_loss: 2.3036e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 5.0816
# Epoch 85/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 49s 56ms/step - loss: 2.0634e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.0959 - val_loss: 1.9908e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 9.5268
# Epoch 86/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 2.1037e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.6459 - val_loss: 1.9119e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 5.8264
# Epoch 87/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 57ms/step - loss: 2.0028e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 8.5583 - val_loss: 1.9141e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 9.9851
# Epoch 88/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - loss: 1.9953e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 1.7321 - val_loss: 1.8104e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 7.4933
# Epoch 89/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 2.0057e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 4.4008 - val_loss: 1.8115e-05 - val_mean_absolute_error: 0.0014 - val_mean_absolute_percentage_error: 6.7857
# Epoch 90/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 50s 56ms/step - loss: 1.9303e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.9550 - val_loss: 1.9015e-05 - val_mean_absolute_error: 0.0017 - val_mean_absolute_percentage_error: 6.3640
# Epoch 91/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 47s 54ms/step - loss: 1.8866e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.3943 - val_loss: 2.2549e-05 - val_mean_absolute_error: 0.0025 - val_mean_absolute_percentage_error: 4.6717
# Epoch 92/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - loss: 1.9082e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.9783 - val_loss: 1.7942e-05 - val_mean_absolute_error: 0.0015 - val_mean_absolute_percentage_error: 8.1045
# Epoch 93/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 45s 51ms/step - loss: 1.8519e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 3.7449 - val_loss: 1.9723e-05 - val_mean_absolute_error: 0.0020 - val_mean_absolute_percentage_error: 9.3642
# Epoch 94/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 47s 52ms/step - loss: 1.8221e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 2.5080 - val_loss: 1.8265e-05 - val_mean_absolute_error: 0.0016 - val_mean_absolute_percentage_error: 9.0452
# Epoch 95/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - loss: 1.8981e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.2560 - val_loss: 1.6727e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 7.3800
# Epoch 96/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - loss: 1.9150e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 6.1343 - val_loss: 1.9310e-05 - val_mean_absolute_error: 0.0018 - val_mean_absolute_percentage_error: 9.8790
# Epoch 97/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 44s 50ms/step - loss: 1.8384e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 4.1982 - val_loss: 2.1430e-05 - val_mean_absolute_error: 0.0024 - val_mean_absolute_percentage_error: 4.5570
# Epoch 98/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 46s 52ms/step - loss: 1.8810e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 2.5473 - val_loss: 1.8283e-05 - val_mean_absolute_error: 0.0019 - val_mean_absolute_percentage_error: 11.2064
# Epoch 99/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 47s 53ms/step - loss: 1.8395e-05 - mean_absolute_error: 0.0016 - mean_absolute_percentage_error: 5.1894 - val_loss: 2.2153e-05 - val_mean_absolute_error: 0.0023 - val_mean_absolute_percentage_error: 6.2150
# Epoch 100/100
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 44s 50ms/step - loss: 1.8218e-05 - mean_absolute_error: 0.0017 - mean_absolute_percentage_error: 3.4286 - val_loss: 1.5959e-05 - val_mean_absolute_error: 0.0013 - val_mean_absolute_percentage_error: 6.5372
# 3009/3009 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_20608\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_20608\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[23904 24331]
#  [23360 24662]]
