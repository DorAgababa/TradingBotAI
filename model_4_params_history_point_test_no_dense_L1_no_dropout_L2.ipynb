# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['next_5_min']
    x = data.drop('next_5_min')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.781022 ┆ -0.780106 ┆ -0.779407 ┆ -0.274536 │
# │ -0.779862 ┆ -0.780807 ┆ -0.780042 ┆ -0.297566 │
# │ -0.78201  ┆ -0.782142 ┆ -0.780891 ┆ -0.467761 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.779856    │
# │ -0.782004    │
# │ -0.778978    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)),return_sequences=(lstm_layer2_size > 0),activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1),return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=75
history_points = 5
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (92100, 4)
# y_train is (92100, 1)
# x_train_prepared is (87188, 5, 4)
# y_train_prepared is (87188, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=50, 
    lstm_layer2_size=0, 
    regular_layer1_size=0, 
    regular_layer2_size=0,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=5, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=200, 
    learning_rate=0.0003, 
    epochs=50
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - loss: 0.2704 - mean_absolute_error: 0.3277 - mean_absolute_percentage_error: 80.8752 - val_loss: 0.0028 - val_mean_absolute_error: 0.0256 - val_mean_absolute_percentage_error: 18.0403
# Epoch 2/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 0.0029 - mean_absolute_error: 0.0259 - mean_absolute_percentage_error: 18.9365 - val_loss: 0.0020 - val_mean_absolute_error: 0.0184 - val_mean_absolute_percentage_error: 15.0699
# Epoch 3/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0021 - mean_absolute_error: 0.0191 - mean_absolute_percentage_error: 14.4440 - val_loss: 0.0017 - val_mean_absolute_error: 0.0146 - val_mean_absolute_percentage_error: 8.9128
# Epoch 4/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0018 - mean_absolute_error: 0.0151 - mean_absolute_percentage_error: 10.4722 - val_loss: 0.0015 - val_mean_absolute_error: 0.0115 - val_mean_absolute_percentage_error: 8.9861
# Epoch 5/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0016 - mean_absolute_error: 0.0119 - mean_absolute_percentage_error: 11.7423 - val_loss: 0.0013 - val_mean_absolute_error: 0.0096 - val_mean_absolute_percentage_error: 7.9513
# Epoch 6/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0092 - mean_absolute_percentage_error: 7.7367 - val_loss: 0.0013 - val_mean_absolute_error: 0.0091 - val_mean_absolute_percentage_error: 10.4956
# Epoch 7/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0012 - mean_absolute_error: 0.0075 - mean_absolute_percentage_error: 8.2819 - val_loss: 0.0010 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 5.7743
# Epoch 8/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0010 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 7.6384 - val_loss: 9.1474e-04 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 5.1713
# Epoch 9/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 8.9966e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 5.9620 - val_loss: 8.2446e-04 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 6.4363
# Epoch 10/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - loss: 8.3835e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 6.1493 - val_loss: 7.1594e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 4.8842
# Epoch 11/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - loss: 6.9747e-04 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 4.9906 - val_loss: 6.3623e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 4.7887
# Epoch 12/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 6.2214e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 5.6577 - val_loss: 5.5860e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 4.5932
# Epoch 13/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 5.4699e-04 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 4.8485 - val_loss: 4.9193e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 4.3598
# Epoch 14/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 13s 25ms/step - loss: 4.9332e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.9808 - val_loss: 4.3173e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.8691
# Epoch 15/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 4.2026e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.8276 - val_loss: 3.8436e-04 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 3.9859
# Epoch 16/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - loss: 3.7611e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.9513 - val_loss: 3.4652e-04 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 3.9362
# Epoch 17/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 26s 34ms/step - loss: 3.3018e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 3.9235 - val_loss: 3.0825e-04 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 4.9959
# Epoch 18/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - loss: 2.9377e-04 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.8802 - val_loss: 2.6058e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.2270
# Epoch 19/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 16s 36ms/step - loss: 2.6225e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 5.2507 - val_loss: 2.3229e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.2121
# Epoch 20/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - loss: 2.2839e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.0505 - val_loss: 2.0791e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.5762
# Epoch 21/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - loss: 2.0366e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 6.2257 - val_loss: 1.8544e-04 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.2364
# Epoch 22/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 24s 49ms/step - loss: 1.8300e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 5.5160 - val_loss: 1.6854e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 4.5103
# Epoch 23/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 20s 43ms/step - loss: 1.6372e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 6.1200 - val_loss: 1.4453e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.2089
# Epoch 24/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - loss: 1.4593e-04 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.8116 - val_loss: 1.2949e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 5.0116
# Epoch 25/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 32s 39ms/step - loss: 1.3428e-04 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 5.8840 - val_loss: 1.1964e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.1976
# Epoch 26/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 35s 69ms/step - loss: 1.1825e-04 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.4561 - val_loss: 1.1760e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 4.3055
# Epoch 27/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - loss: 1.0662e-04 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 5.8358 - val_loss: 9.4842e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 4.1520
# Epoch 28/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 22s 49ms/step - loss: 1.0078e-04 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.0328 - val_loss: 9.3399e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.1665
# Epoch 29/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 9.5776e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.7400 - val_loss: 8.3070e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 4.6734
# Epoch 30/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 24s 54ms/step - loss: 9.6837e-05 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 5.7022 - val_loss: 8.0335e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.2334
# Epoch 31/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - loss: 1.1470e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 5.1956 - val_loss: 7.0764e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 4.0187
# Epoch 32/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 24s 53ms/step - loss: 7.5571e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.5041 - val_loss: 6.7226e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.9926
# Epoch 33/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 18s 35ms/step - loss: 6.9590e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 3.7267 - val_loss: 6.4777e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 4.1869
# Epoch 34/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 30s 55ms/step - loss: 7.0551e-05 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.7871 - val_loss: 6.6660e-05 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.3196
# Epoch 35/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 35s 73ms/step - loss: 6.3641e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.8019 - val_loss: 5.8757e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.9259
# Epoch 36/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 15s 31ms/step - loss: 6.6598e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 6.0670 - val_loss: 5.7093e-05 - val_mean_absolute_error: 0.0027 - val_mean_absolute_percentage_error: 3.8738
# Epoch 37/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - loss: 6.1310e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.4347 - val_loss: 7.0124e-05 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 4.4055
# Epoch 38/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 19s 40ms/step - loss: 6.7603e-05 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 4.2601 - val_loss: 5.4345e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.1875
# Epoch 39/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 5.8202e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.5281 - val_loss: 5.3904e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.3740
# Epoch 40/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 24s 46ms/step - loss: 5.5335e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.0501 - val_loss: 4.9647e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 4.1657
# Epoch 41/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 5.1497e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.3616 - val_loss: 4.7050e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 3.2873
# Epoch 42/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 22s 44ms/step - loss: 5.2244e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 5.1834 - val_loss: 6.7235e-05 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 5.7104
# Epoch 43/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - loss: 5.2822e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.8685 - val_loss: 4.9395e-05 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.3189
# Epoch 44/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - loss: 5.5357e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 6.3274 - val_loss: 6.2681e-05 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 3.4960
# Epoch 45/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 23s 43ms/step - loss: 5.3353e-05 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.4848 - val_loss: 6.1406e-05 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 3.7014
# Epoch 46/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 15s 33ms/step - loss: 5.0258e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 4.6346 - val_loss: 5.3626e-05 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 4.8031
# Epoch 47/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 14s 27ms/step - loss: 4.9058e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.4610 - val_loss: 4.1732e-05 - val_mean_absolute_error: 0.0026 - val_mean_absolute_percentage_error: 4.0899
# Epoch 48/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - loss: 4.8841e-05 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.5134 - val_loss: 5.4051e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 4.0772
# Epoch 49/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - loss: 4.5728e-05 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.1861 - val_loss: 4.4264e-05 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.5489
# Epoch 50/50
# 436/436 ━━━━━━━━━━━━━━━━━━━━ 15s 29ms/step - loss: 4.5787e-05 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 5.1637 - val_loss: 5.5600e-05 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 3.6585
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 36s 42ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_22356\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_22356\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[4375 4851]
#  [4868 4578]]

# %%
def calc_real_profit(y,ypred):
    profit =0 
    
    for i in range(1, len(y)):
        if (y[i]-y[i-1] > 0 and ypred[i]-y[i-1] > 0) or (y[i]-y[i-1] < 0 and ypred[i]-y[i-1] < 0):
            profit += np.abs(y[i]-y[i-1])
        else :
            profit -= np.abs(y[i]-y[i-1])

    print(f"your profit is {profit}")

calc_real_profit(y_val_prepared,y_val_predicted)
# Out:
# your profit is [46575.8]
