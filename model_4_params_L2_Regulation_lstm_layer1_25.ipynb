# %%
import polars as pl
import pandas as pd
import numpy as np
from enum import Enum
# %matplotlib inline
import matplotlib.pyplot as plt
import sklearn.preprocessing as preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import keras
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate, Input,  TimeDistributed, concatenate
from keras import regularizers, optimizers
from keras.utils import plot_model
from keras.metrics import MeanAbsoluteError, MeanAbsolutePercentageError
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf



#Data manipulation

#This test using this data collumns
columns_to_normalize = ["close", "ema5", "ema20" , "macd520"]

#reading the data that already shuffled and arranged
def read_data(train_file = 'train_data.csv', val_file = 'val_data.csv', test_file = 'test_data.csv'):
    train_data = pl.read_csv(train_file)
    val_data = pl.read_csv(val_file)
    test_data = pl.read_csv(test_file)
    return train_data, val_data, test_data

#get data of x and y and return x and y, slice y
def extract_y(data):
    y = data['next_5_min']
    x = data.drop('next_5_min')
    return x,y


#we should not use min max scale cause the max changing over the time.
#we need to deal with two kinds of things : 1. train data - we need to create a scaler and fit it to the train, and then create a normalized data , 2. test/validation data - we should get as input the scaler of the train, and do normalize by him
def min_max_scaler(data):
    scaler = preprocessing.MinMaxScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler

#This scaler do the scaling as gaussian scaler
def z_score_normalize(data):
    scaler = preprocessing.StandardScaler()
    scaled_data = scaler.fit_transform(data)
    return scaled_data, scaler
    

def normalized_x_y(x: pl.DataFrame, y: pl.DataFrame, columns_to_normalize: list):
    # Convert Polars DataFrame to NumPy array for normalization
    x_values = x.select(columns_to_normalize).to_numpy()
    y_values = y.to_numpy().reshape(-1, 1)
    # Normalize
    normalized_x_values, scaler_x = z_score_normalize(x_values)
    normalized_y_values, scaler_y = z_score_normalize(y_values)
    # Convert back to Polars DataFrame
    normalized_x = pl.DataFrame(normalized_x_values, schema=columns_to_normalize)
    normalized_y = pl.DataFrame(normalized_y_values, schema=['normalized_y'])

    return normalized_x, normalized_y, scaler_x, scaler_y

# %%
train_data, val_data, test_data = read_data()
x_train, y_train = extract_y(train_data)
x_val, y_val = extract_y(val_data)
x_test, y_test = extract_y(test_data)

# %%
# Split data to train val and test and normalize the data
x_train, y_train, x_train_scaler, y_train_scaler = normalized_x_y(x_train, y_train, columns_to_normalize)
x_val, y_val, x_val_scaler, y_val_scaler = normalized_x_y(x_val, y_val, columns_to_normalize)
x_test, y_test, x_test_scaler, y_test_scaler = normalized_x_y(x_test, y_test, columns_to_normalize)
print(x_test[:3])
print(y_test[:3])
# Out:
# shape: (3, 4)
# ┌───────────┬───────────┬───────────┬───────────┐
# │ close     ┆ ema5      ┆ ema20     ┆ macd520   │
# │ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╡
# │ -0.781022 ┆ -0.780106 ┆ -0.779407 ┆ -0.274536 │
# │ -0.779862 ┆ -0.780807 ┆ -0.780042 ┆ -0.297566 │
# │ -0.78201  ┆ -0.782142 ┆ -0.780891 ┆ -0.467761 │
# └───────────┴───────────┴───────────┴───────────┘
# shape: (3, 1)
# ┌──────────────┐
# │ normalized_y │
# │ ---          │
# │ f64          │
# ╞══════════════╡
# │ -0.779856    │
# │ -0.782004    │
# │ -0.778978    │
# └──────────────┘

# %%
# all this block will preapre the data as the needed size for the lstm model
def prepare_lstm_data(x, y, history_points, day_size):
    x_sequences = create_sequences(x, history_points, day_size)
    y_sequences = create_target_sequences(y, history_points, day_size)
    return x_sequences, y_sequences

def create_sequences(data, history_points, day_size):
    sequences = []
    
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate sequences within the current day
        for i in range(day_start, day_end - history_points + 1):
            sequences.append(data[i:i + history_points])
    
    return np.array(sequences)

#creating y data
def create_target_sequences(data, history_points, day_size):
    target_sequences = []
    # Outer loop: iterate over each day
    for day_start in range(0, len(data), day_size):
        day_end = min(day_start + day_size, len(data))
        
        # Inner loop: generate target sequences within the current day
        for i in range(day_start+history_points-1, day_end ):
            target_sequences.append(data[i])  # Get the y of the last element in the sequence(the y of the 10 number)
    return np.array(target_sequences).reshape(-1, 1)  # Reshape to (batch_size, 1, 1)

# %%
#Generic function that allow to create model with multiplie optione (regulations,dropout, batch sizes)
def model_creator(lstm_layer1_size, 
                  lstm_layer2_size=None, 
                  regular_layer1_size=None, 
                  regular_layer2_size=None,
                  L1=0, L2=0, 
                  dropout=0, 
                  history_points=10, 
                  x_train=None, y_train=None,
                  x_val=None, y_val=None,
                  batch_size=512, 
                  learning_rate=0.0005, 
                  epochs=50):
    # Building the model
    model = Sequential()

    # Adding first LSTM layer with optional regularization and dropout
    if L1:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l1(L1), activation="relu"))
    elif L2:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), 
                       kernel_regularizer=regularizers.l2(L2), activation="relu"))
    else:
        model.add(LSTM(lstm_layer1_size, input_shape=(history_points, len(columns_to_normalize)), activation="relu"))
    
    if dropout:
        model.add(Dropout(dropout))

    # Adding second LSTM layer if reuired too
    if lstm_layer2_size:
        if L1:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu", return_sequences=False))
        elif L2:
            model.add(LSTM(lstm_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu", return_sequences=False))
        else:
            model.add(LSTM(lstm_layer2_size, activation="relu", return_sequences=False))
        
        if dropout:
            model.add(Dropout(dropout))
    
    # Adding first regular Dense layer if reuired too
    if regular_layer1_size:
        if L1:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer1_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer1_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Adding second regular Dense layer if reuired too
    if regular_layer2_size:
        if L1:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l1(L1), activation="relu"))
        elif L2:
            model.add(Dense(regular_layer2_size, kernel_regularizer=regularizers.l2(L2), activation="relu"))
        else:
            model.add(Dense(regular_layer2_size, activation="relu"))
        
        if dropout:
            model.add(Dropout(dropout))

    # Final output layer
    model.add(Dense(1, activation="linear"))

    #Our problem is Regression(we predict continuously val) and Accuracy suits for classification problems and for our one
    # Compile the model
    adam = optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=adam, loss="mse", metrics=[MeanAbsoluteError(),MeanAbsolutePercentageError()])

    # Training the model with train data and already
    history = model.fit(x_train,
                        y_train,
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val))

    # Get validation predictions
    y_val_predicted = model.predict(x_val)
    
    # Extract metrics
    loss = history.history['loss']
    mae = history.history['mean_absolute_error']
    mape_values = history.history['mean_absolute_percentage_error']
    success_ratio = [100 - mape for mape in mape_values]
    val_loss = history.history.get('val_loss')
    val_mae = history.history.get('val_mean_absolute_error')
    val_mape_values = history.history['val_mean_absolute_percentage_error']
    val_success_ratio = [100 - mape for mape in val_mape_values]

    return y_val_predicted, loss, val_loss, mae, val_mae,success_ratio,val_success_ratio

# %%
def find_intersections(x, y1, y2):
    intersections = []
    for i in range(1, len(x)):
        if (y1[i-1] - y2[i-1]) * (y1[i] - y2[i]) < 0:
            # Calculate intersection point using linear interpolation
            x1, x2 = x[i-1], x[i]
            y1_1, y1_2 = y1[i-1], y1[i]
            y2_1, y2_2 = y2[i-1], y2[i]
            
            x_inter = x1 + (y2_1 - y1_1) * (x2 - x1) / (y1_2 - y1_1 - (y2_2 - y2_1))
            y_inter = y1_1 + (x_inter - x1) * (y1_2 - y1_1) / (x2 - x1)
            intersections.append((x_inter, y_inter))
    return intersections

def plot_errors(loss_train, loss_val, mae_train, mae_val, succees_ratio_train,success_ratio_val, title_prefix='Model Performance'):
    epochs = np.arange(len(loss_train))  # Assuming epochs are sequential indices

    # Calculate intersections
    loss_intersections = find_intersections(epochs, loss_train, loss_val)
    mae_intersections = find_intersections(epochs, mae_train, mae_val)
    
    plt.figure(figsize=(21, 6))
    plt.subplot(1, 3, 1)
    plt.plot(succees_ratio_train, label='Training success_ratio', color='blue')
    plt.plot(success_ratio_val, label='Validation success_ratio', color='orange')
    plt.title(f'{title_prefix} - success_ratio(Our custom score)')
    plt.xlabel('Epochs')
    plt.ylabel('SUCCESS RATIO %')
    plt.legend()
    plt.grid(True)



    # Plot Loss
    plt.subplot(1, 3, 2)
    plt.plot(loss_train, label='Training loss', color='blue')
    plt.plot(loss_val, label='Validation loss', color='orange')
    plt.title(f'{title_prefix} - LOSS')
    plt.xlabel('Epochs')
    plt.ylabel('LOSS')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for LOSS
    for x_inter, y_inter in loss_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    # Plot MAE
    plt.subplot(1, 3, 3)
    plt.plot(mae_train, label='Training MAE', color='green')
    plt.plot(mae_val, label='Validation MAE', color='red')
    plt.title(f'{title_prefix} - Mean Absolute Error (MAE)')
    plt.xlabel('Epochs')
    plt.ylabel('MAE')
    plt.legend()
    plt.grid(True)
    
    # Annotate intersections for MAE
    for x_inter, y_inter in mae_intersections:
        plt.plot(x_inter, y_inter, 'ko')  # Mark intersection points
        plt.text(x_inter, y_inter, f'({x_inter:.1f}, {y_inter:.2f})', fontsize=9, verticalalignment='bottom', horizontalalignment='right')

    plt.tight_layout()
    plt.show()

def plot_stock_price_result(y, y_predicted):
    # Create the plot
    plt.figure(figsize=(12, 6))

    # Plot y_val_predicted
    plt.plot(y_predicted, color='blue', label='y_val_predicted')

    # Plot feature from x_val_prepared
    plt.plot(y, color='red', label='y_val')

    # Add labels and legend
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('Stock price predicted vs real')
    plt.legend()

    # Show plot
    plt.show()

# %%
#prepare your data to LSTM model
#Data should be recieved as 3d array ,array of 2d arrays ,where each 2d array is the previous data to the model before predicting the future 
day_size=75
history_points = 10
x_train_prepared, y_train_prepared = prepare_lstm_data(x_train, y_train, history_points, day_size)
x_val_prepared, y_val_prepared = prepare_lstm_data(x_val, y_val, history_points, day_size)
print(f"x_train is {x_train.shape}"  )
print(f"y_train is {y_train.shape}"  )
print(f"x_train_prepared is {x_train_prepared.shape}"  )
print(f"y_train_prepared is {y_train_prepared.shape}"  )
# Out:
# x_train is (92100, 4)
# y_train is (92100, 1)
# x_train_prepared is (81048, 10, 4)
# y_train_prepared is (81048, 1)

# %%
#model based on the other notebook of https://www.kaggle.com/code/alirezanematolahy/tehran-stock-prediction-using-lstm-model#The-Dataset 
y_val_predicted, train_loss, val_loss, train_mae, val_mae,succees,val_success = model_creator(
    lstm_layer1_size=150, 
    lstm_layer2_size=None, 
    regular_layer1_size=64, 
    regular_layer2_size=None,
    L1=0, 
    L2=0.0002, 
    dropout=0, 
    history_points=10, 
    x_train=x_train_prepared,  # Replace with your actual training data
    y_train=y_train_prepared,  # Replace with your actual training labels
    x_val=x_val_prepared,      # Replace with your actual validation data
    y_val=y_val_prepared,      # Replace with your actual validation labels
    batch_size=512, 
    learning_rate=0.0005, 
    epochs=100
)
# Out:
# C:\Users\David\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 27s 113ms/step - loss: 0.2288 - mean_absolute_error: 0.2545 - mean_absolute_percentage_error: 64.2689 - val_loss: 0.0160 - val_mean_absolute_error: 0.0146 - val_mean_absolute_percentage_error: 13.7437
# Epoch 2/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 108ms/step - loss: 0.0152 - mean_absolute_error: 0.0141 - mean_absolute_percentage_error: 10.4847 - val_loss: 0.0131 - val_mean_absolute_error: 0.0086 - val_mean_absolute_percentage_error: 13.1696
# Epoch 3/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 115ms/step - loss: 0.0127 - mean_absolute_error: 0.0086 - mean_absolute_percentage_error: 15.9563 - val_loss: 0.0113 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 11.9979
# Epoch 4/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - loss: 0.0110 - mean_absolute_error: 0.0058 - mean_absolute_percentage_error: 11.3229 - val_loss: 0.0099 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 7.1457
# Epoch 5/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 24s 141ms/step - loss: 0.0096 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 8.1238 - val_loss: 0.0088 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 6.9001
# Epoch 6/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 138ms/step - loss: 0.0086 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 6.8484 - val_loss: 0.0078 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 4.6858
# Epoch 7/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 29s 174ms/step - loss: 0.0076 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 6.8597 - val_loss: 0.0070 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.1100
# Epoch 8/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 29s 177ms/step - loss: 0.0068 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.1285 - val_loss: 0.0063 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.4821
# Epoch 9/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 131ms/step - loss: 0.0061 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.5760 - val_loss: 0.0056 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.0928
# Epoch 10/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 46s 154ms/step - loss: 0.0055 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 6.3250 - val_loss: 0.0050 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.1890
# Epoch 11/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 51s 208ms/step - loss: 0.0049 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 5.6423 - val_loss: 0.0045 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 4.0133
# Epoch 12/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 36s 222ms/step - loss: 0.0044 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 5.8901 - val_loss: 0.0040 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 4.0782
# Epoch 13/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 34s 162ms/step - loss: 0.0039 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 5.7160 - val_loss: 0.0036 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 4.1884
# Epoch 14/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 36s 220ms/step - loss: 0.0035 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 5.3041 - val_loss: 0.0032 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 4.1072
# Epoch 15/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 38s 193ms/step - loss: 0.0031 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 5.0407 - val_loss: 0.0029 - val_mean_absolute_error: 0.0033 - val_mean_absolute_percentage_error: 3.6239
# Epoch 16/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 40s 204ms/step - loss: 0.0028 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.5711 - val_loss: 0.0026 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.8544
# Epoch 17/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 30s 169ms/step - loss: 0.0025 - mean_absolute_error: 0.0029 - mean_absolute_percentage_error: 4.1693 - val_loss: 0.0023 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.6096
# Epoch 18/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 43s 170ms/step - loss: 0.0022 - mean_absolute_error: 0.0030 - mean_absolute_percentage_error: 4.6864 - val_loss: 0.0021 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.6695
# Epoch 19/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 31s 193ms/step - loss: 0.0020 - mean_absolute_error: 0.0031 - mean_absolute_percentage_error: 3.8908 - val_loss: 0.0018 - val_mean_absolute_error: 0.0034 - val_mean_absolute_percentage_error: 4.0988
# Epoch 20/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 35s 180ms/step - loss: 0.0018 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 4.6881 - val_loss: 0.0016 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.5768
# Epoch 21/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 36s 225ms/step - loss: 0.0016 - mean_absolute_error: 0.0033 - mean_absolute_percentage_error: 4.4485 - val_loss: 0.0014 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.6212
# Epoch 22/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 33s 207ms/step - loss: 0.0014 - mean_absolute_error: 0.0032 - mean_absolute_percentage_error: 5.1068 - val_loss: 0.0013 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.0511
# Epoch 23/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 28s 173ms/step - loss: 0.0012 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 4.1871 - val_loss: 0.0011 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 3.7094
# Epoch 24/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 31s 174ms/step - loss: 0.0011 - mean_absolute_error: 0.0034 - mean_absolute_percentage_error: 5.2746 - val_loss: 0.0010 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 5.0914
# Epoch 25/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 41s 170ms/step - loss: 9.7346e-04 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 4.1964 - val_loss: 9.1989e-04 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 4.2268
# Epoch 26/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 129ms/step - loss: 8.7235e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 4.4522 - val_loss: 8.0616e-04 - val_mean_absolute_error: 0.0051 - val_mean_absolute_percentage_error: 3.8909
# Epoch 27/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - loss: 7.7292e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 3.9982 - val_loss: 6.9749e-04 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 3.5533
# Epoch 28/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 30s 182ms/step - loss: 6.8455e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 3.8013 - val_loss: 6.2623e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 4.1882
# Epoch 29/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 32s 117ms/step - loss: 6.1824e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 5.1844 - val_loss: 6.0968e-04 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 5.4153
# Epoch 30/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 133ms/step - loss: 5.8248e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 4.8136 - val_loss: 4.9564e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.4971
# Epoch 31/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - loss: 5.0348e-04 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 4.0329 - val_loss: 4.7447e-04 - val_mean_absolute_error: 0.0053 - val_mean_absolute_percentage_error: 5.8590
# Epoch 32/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 123ms/step - loss: 4.5112e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 3.7546 - val_loss: 5.0656e-04 - val_mean_absolute_error: 0.0093 - val_mean_absolute_percentage_error: 9.4185
# Epoch 33/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 118ms/step - loss: 4.3395e-04 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 4.2341 - val_loss: 3.6730e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.5324
# Epoch 34/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - loss: 3.7377e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 3.9962 - val_loss: 3.4496e-04 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 3.4840
# Epoch 35/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 110ms/step - loss: 3.5586e-04 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 5.0307 - val_loss: 3.1085e-04 - val_mean_absolute_error: 0.0030 - val_mean_absolute_percentage_error: 3.8499
# Epoch 36/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 17s 109ms/step - loss: 3.2928e-04 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 4.2100 - val_loss: 2.8771e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.1382
# Epoch 37/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 23s 123ms/step - loss: 2.9368e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.3969 - val_loss: 2.7709e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 3.5362
# Epoch 38/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 16s 103ms/step - loss: 2.9696e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 4.1804 - val_loss: 2.5671e-04 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 3.3999
# Epoch 39/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 117ms/step - loss: 2.6709e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 4.5266 - val_loss: 2.4990e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 3.7649
# Epoch 40/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 114ms/step - loss: 2.5264e-04 - mean_absolute_error: 0.0046 - mean_absolute_percentage_error: 5.2965 - val_loss: 2.4854e-04 - val_mean_absolute_error: 0.0052 - val_mean_absolute_percentage_error: 4.0002
# Epoch 41/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 112ms/step - loss: 2.7503e-04 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 4.9079 - val_loss: 2.3850e-04 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 5.0122
# Epoch 42/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 115ms/step - loss: 2.8348e-04 - mean_absolute_error: 0.0059 - mean_absolute_percentage_error: 4.4892 - val_loss: 1.9863e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.9597
# Epoch 43/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 16s 102ms/step - loss: 2.0567e-04 - mean_absolute_error: 0.0035 - mean_absolute_percentage_error: 3.8651 - val_loss: 2.8230e-04 - val_mean_absolute_error: 0.0086 - val_mean_absolute_percentage_error: 4.9942
# Epoch 44/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 97ms/step - loss: 2.6492e-04 - mean_absolute_error: 0.0067 - mean_absolute_percentage_error: 4.3704 - val_loss: 1.9180e-04 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.6016
# Epoch 45/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 98ms/step - loss: 1.9739e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 4.0271 - val_loss: 1.7324e-04 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.6030
# Epoch 46/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 110ms/step - loss: 1.8835e-04 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 4.2843 - val_loss: 1.7813e-04 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 3.8574
# Epoch 47/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - loss: 2.1527e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 4.4833 - val_loss: 1.6849e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 4.9787
# Epoch 48/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 100ms/step - loss: 1.8066e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 3.6019 - val_loss: 1.6733e-04 - val_mean_absolute_error: 0.0038 - val_mean_absolute_percentage_error: 5.8238
# Epoch 49/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - loss: 1.9884e-04 - mean_absolute_error: 0.0056 - mean_absolute_percentage_error: 4.1354 - val_loss: 2.0910e-04 - val_mean_absolute_error: 0.0076 - val_mean_absolute_percentage_error: 5.0827
# Epoch 50/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 100ms/step - loss: 1.8071e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 3.9452 - val_loss: 1.5405e-04 - val_mean_absolute_error: 0.0039 - val_mean_absolute_percentage_error: 4.9788
# Epoch 51/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 96ms/step - loss: 1.6795e-04 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 4.4708 - val_loss: 1.4918e-04 - val_mean_absolute_error: 0.0041 - val_mean_absolute_percentage_error: 3.9358
# Epoch 52/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 15s 95ms/step - loss: 1.5199e-04 - mean_absolute_error: 0.0039 - mean_absolute_percentage_error: 4.2233 - val_loss: 1.6019e-04 - val_mean_absolute_error: 0.0054 - val_mean_absolute_percentage_error: 4.7349
# Epoch 53/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 103ms/step - loss: 1.6760e-04 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 5.1877 - val_loss: 1.3708e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 5.3168
# Epoch 54/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 17s 108ms/step - loss: 1.7105e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 4.3564 - val_loss: 1.3101e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.2186
# Epoch 55/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - loss: 1.3769e-04 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 3.7200 - val_loss: 1.6524e-04 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 5.0292
# Epoch 56/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 16s 102ms/step - loss: 1.4635e-04 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 4.5932 - val_loss: 1.3929e-04 - val_mean_absolute_error: 0.0046 - val_mean_absolute_percentage_error: 6.8337
# Epoch 57/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 19s 90ms/step - loss: 1.4024e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 4.8343 - val_loss: 1.1946e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 3.8921
# Epoch 58/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 18s 76ms/step - loss: 1.5680e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 4.7262 - val_loss: 1.6558e-04 - val_mean_absolute_error: 0.0061 - val_mean_absolute_percentage_error: 4.0583
# Epoch 59/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 73ms/step - loss: 1.8648e-04 - mean_absolute_error: 0.0068 - mean_absolute_percentage_error: 5.6221 - val_loss: 1.2843e-04 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 4.2129
# Epoch 60/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - loss: 1.2496e-04 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 4.3811 - val_loss: 1.1289e-04 - val_mean_absolute_error: 0.0031 - val_mean_absolute_percentage_error: 4.4074
# Epoch 61/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - loss: 1.5005e-04 - mean_absolute_error: 0.0052 - mean_absolute_percentage_error: 6.2940 - val_loss: 1.1470e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 4.2851
# Epoch 62/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 1.3818e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 5.5446 - val_loss: 1.1317e-04 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 3.4072
# Epoch 63/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 1.3969e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 4.4017 - val_loss: 2.3105e-04 - val_mean_absolute_error: 0.0075 - val_mean_absolute_percentage_error: 6.0894
# Epoch 64/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 1.3788e-04 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 4.9668 - val_loss: 1.2413e-04 - val_mean_absolute_error: 0.0045 - val_mean_absolute_percentage_error: 4.2091
# Epoch 65/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - loss: 1.4222e-04 - mean_absolute_error: 0.0050 - mean_absolute_percentage_error: 3.8830 - val_loss: 1.0558e-04 - val_mean_absolute_error: 0.0032 - val_mean_absolute_percentage_error: 3.4263
# Epoch 66/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - loss: 1.2617e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 4.0527 - val_loss: 1.3628e-04 - val_mean_absolute_error: 0.0059 - val_mean_absolute_percentage_error: 4.1808
# Epoch 67/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - loss: 1.5251e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 5.2824 - val_loss: 1.0579e-04 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 4.8030
# Epoch 68/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 1.1280e-04 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 3.7663 - val_loss: 1.0741e-04 - val_mean_absolute_error: 0.0042 - val_mean_absolute_percentage_error: 3.6320
# Epoch 69/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - loss: 1.2730e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 4.1613 - val_loss: 1.3023e-04 - val_mean_absolute_error: 0.0051 - val_mean_absolute_percentage_error: 6.5498
# Epoch 70/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - loss: 1.2528e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 5.3978 - val_loss: 1.1391e-04 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 3.9587
# Epoch 71/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - loss: 1.2410e-04 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 4.5963 - val_loss: 9.6710e-05 - val_mean_absolute_error: 0.0035 - val_mean_absolute_percentage_error: 3.8431
# Epoch 72/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - loss: 1.0515e-04 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 3.5444 - val_loss: 1.3602e-04 - val_mean_absolute_error: 0.0069 - val_mean_absolute_percentage_error: 7.8698
# Epoch 73/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - loss: 1.3888e-04 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 4.8424 - val_loss: 1.1325e-04 - val_mean_absolute_error: 0.0053 - val_mean_absolute_percentage_error: 5.8028
# Epoch 74/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 1.1704e-04 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 5.1073 - val_loss: 1.4759e-04 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 7.2071
# Epoch 75/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 1.8170e-04 - mean_absolute_error: 0.0075 - mean_absolute_percentage_error: 5.9725 - val_loss: 1.6765e-04 - val_mean_absolute_error: 0.0067 - val_mean_absolute_percentage_error: 4.5003
# Epoch 76/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 1.2124e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 4.4975 - val_loss: 1.3118e-04 - val_mean_absolute_error: 0.0051 - val_mean_absolute_percentage_error: 3.6865
# Epoch 77/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - loss: 1.2780e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 6.3077 - val_loss: 1.3638e-04 - val_mean_absolute_error: 0.0062 - val_mean_absolute_percentage_error: 4.8731
# Epoch 78/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 1.0581e-04 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 5.9605 - val_loss: 1.0844e-04 - val_mean_absolute_error: 0.0049 - val_mean_absolute_percentage_error: 4.3451
# Epoch 79/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - loss: 1.1881e-04 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 5.4921 - val_loss: 1.4423e-04 - val_mean_absolute_error: 0.0073 - val_mean_absolute_percentage_error: 8.5847
# Epoch 80/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 1.3451e-04 - mean_absolute_error: 0.0055 - mean_absolute_percentage_error: 5.3525 - val_loss: 1.2946e-04 - val_mean_absolute_error: 0.0069 - val_mean_absolute_percentage_error: 8.6318
# Epoch 81/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - loss: 1.1049e-04 - mean_absolute_error: 0.0048 - mean_absolute_percentage_error: 4.6264 - val_loss: 1.1626e-04 - val_mean_absolute_error: 0.0050 - val_mean_absolute_percentage_error: 5.6396
# Epoch 82/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 1.1500e-04 - mean_absolute_error: 0.0045 - mean_absolute_percentage_error: 6.0534 - val_loss: 2.4028e-04 - val_mean_absolute_error: 0.0116 - val_mean_absolute_percentage_error: 10.1371
# Epoch 83/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 1.2386e-04 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 5.1961 - val_loss: 9.4291e-05 - val_mean_absolute_error: 0.0040 - val_mean_absolute_percentage_error: 3.8393
# Epoch 84/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 9.3740e-05 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 4.5674 - val_loss: 1.2788e-04 - val_mean_absolute_error: 0.0056 - val_mean_absolute_percentage_error: 7.6662
# Epoch 85/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 70ms/step - loss: 1.8516e-04 - mean_absolute_error: 0.0064 - mean_absolute_percentage_error: 7.2261 - val_loss: 8.6944e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 3.3881
# Epoch 86/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - loss: 9.5794e-05 - mean_absolute_error: 0.0036 - mean_absolute_percentage_error: 3.4137 - val_loss: 1.0706e-04 - val_mean_absolute_error: 0.0048 - val_mean_absolute_percentage_error: 5.1899
# Epoch 87/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 64ms/step - loss: 9.9725e-05 - mean_absolute_error: 0.0040 - mean_absolute_percentage_error: 5.0285 - val_loss: 8.2102e-05 - val_mean_absolute_error: 0.0028 - val_mean_absolute_percentage_error: 3.4787
# Epoch 88/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - loss: 9.2125e-05 - mean_absolute_error: 0.0038 - mean_absolute_percentage_error: 3.7075 - val_loss: 9.2530e-05 - val_mean_absolute_error: 0.0044 - val_mean_absolute_percentage_error: 3.5049
# Epoch 89/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 22s 84ms/step - loss: 1.0195e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 4.6506 - val_loss: 8.8127e-05 - val_mean_absolute_error: 0.0036 - val_mean_absolute_percentage_error: 3.9764
# Epoch 90/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 81ms/step - loss: 9.8395e-05 - mean_absolute_error: 0.0041 - mean_absolute_percentage_error: 3.4977 - val_loss: 1.0185e-04 - val_mean_absolute_error: 0.0047 - val_mean_absolute_percentage_error: 5.4526
# Epoch 91/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - loss: 9.8032e-05 - mean_absolute_error: 0.0044 - mean_absolute_percentage_error: 4.0201 - val_loss: 1.6006e-04 - val_mean_absolute_error: 0.0066 - val_mean_absolute_percentage_error: 6.7471
# Epoch 92/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 12s 78ms/step - loss: 9.8736e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 3.6021 - val_loss: 1.1550e-04 - val_mean_absolute_error: 0.0064 - val_mean_absolute_percentage_error: 7.3074
# Epoch 93/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 1.5198e-04 - mean_absolute_error: 0.0065 - mean_absolute_percentage_error: 5.3511 - val_loss: 1.5353e-04 - val_mean_absolute_error: 0.0076 - val_mean_absolute_percentage_error: 5.4596
# Epoch 94/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 81ms/step - loss: 1.0229e-04 - mean_absolute_error: 0.0043 - mean_absolute_percentage_error: 4.2343 - val_loss: 8.8085e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 7.0807
# Epoch 95/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 82ms/step - loss: 1.3051e-04 - mean_absolute_error: 0.0054 - mean_absolute_percentage_error: 4.6923 - val_loss: 7.7542e-05 - val_mean_absolute_error: 0.0029 - val_mean_absolute_percentage_error: 4.9441
# Epoch 96/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 81ms/step - loss: 8.3644e-05 - mean_absolute_error: 0.0037 - mean_absolute_percentage_error: 3.2084 - val_loss: 9.1417e-05 - val_mean_absolute_error: 0.0037 - val_mean_absolute_percentage_error: 3.8810
# Epoch 97/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 20s 77ms/step - loss: 1.0387e-04 - mean_absolute_error: 0.0047 - mean_absolute_percentage_error: 5.8019 - val_loss: 1.5990e-04 - val_mean_absolute_error: 0.0067 - val_mean_absolute_percentage_error: 5.9997
# Epoch 98/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - loss: 9.4971e-05 - mean_absolute_error: 0.0042 - mean_absolute_percentage_error: 5.1488 - val_loss: 1.0408e-04 - val_mean_absolute_error: 0.0058 - val_mean_absolute_percentage_error: 6.2070
# Epoch 99/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - loss: 1.0610e-04 - mean_absolute_error: 0.0051 - mean_absolute_percentage_error: 4.6861 - val_loss: 8.6325e-05 - val_mean_absolute_error: 0.0043 - val_mean_absolute_percentage_error: 5.1168
# Epoch 100/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 49ms/step - loss: 1.1717e-04 - mean_absolute_error: 0.0053 - mean_absolute_percentage_error: 4.2555 - val_loss: 1.7689e-04 - val_mean_absolute_error: 0.0091 - val_mean_absolute_percentage_error: 5.9551
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
y_val_predicted = y_val_scaler.inverse_transform(y_val_predicted)
y_val_prepared = y_val_scaler.inverse_transform(y_val_prepared)

# %%
plot_stock_price_result(y_val_prepared,y_val_predicted)

# %%
plot_errors(train_loss, val_loss, train_mae, val_mae ,succees,val_success , title_prefix='Model Performance')

# %%
print("We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.")
# Out:
# We can figure out that epoch 8 is good for this model, and will avoid start of overfitting and also good accuracy for validation here.

# %%
#the function should get scaled data
def plot_success_pie( y, ypred):
    # Initialize an array of zeros with the same length as ypred
    success = np.zeros(len(ypred)-1, dtype=int)
    y = y.reshape(-1)
    ypred = ypred.reshape(-1)
    for i in range(1, len(y)):
        if (y[i] > y[i - 1] and ypred[i] > ypred[i - 1]) or (y[i] < y[i - 1] and ypred[i] < ypred[i - 1]):
            success[i-1] = 1
        else:
            success[i-1] = 0
    
    # Count the occurrences of 1s and 0s
    counts = np.bincount(success)
    
    # Labels for the pie chart
    labels = ['Incorrect decision', 'Correct decision']
    
    # Plot pie chart
    plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['red', 'green'])
    plt.title('Trend detection')
    print("The chart show us the precentage of the trend (up & down movement) prediction")
    plt.show()




def print_conf_matrix(y,ypred): 
    real_trend =[] #0 represent stock goes down ,1 goes up
    predicted_trend = []
    for i in range(1, len(y)):
        real_trend.append(int(y[i] > y[i - 1]))
        predicted_trend.append(int(ypred[i] > ypred[i - 1]))
    
    cm = confusion_matrix(real_trend, predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Down', 'Up'])
     # Print confusion matrix
    print("Confusion Matrix:")
    print(cm)

    # Plot confusion matrix
    disp.plot(cmap='Blues')
    plt.show()

# %%
plot_success_pie(y_val_prepared,y_val_predicted)
# Out:
# The chart show us the precentage of the trend (up & down movement) prediction

# %%
print_conf_matrix(y_val_prepared,y_val_predicted)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_22516\2737559405.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   real_trend.append(int(y[i] > y[i - 1]))
# C:\Users\David\AppData\Local\Temp\ipykernel_22516\2737559405.py:33: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_trend.append(int(ypred[i] > ypred[i - 1]))
# Confusion Matrix:
# [[4030 4556]
#  [4529 4242]]
